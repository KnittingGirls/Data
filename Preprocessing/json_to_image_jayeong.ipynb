# %% [markdown]
# json -> image

# %%
import json
import os
import cv2
import numpy as np

DATA_DIR = r"C:\Users\swu\Desktop\raw data" # jpg, json 있는 경로
label_dir = os.path.join(DATA_DIR, 'label')
os.makedirs(label_dir, exist_ok=True)

category_colors = {
    1: (255, 255, 0), # 청록 -> single_jersey
    2: (0, 0, 255),   # 빨강 -> rib
    3: (0, 255, 0),   # 초록 -> purl
    4: (255, 0, 0),   # 파랑 -> interlock (삭제)
    5: (147, 20, 255),# 핑크 -> moss
    6: (0, 255, 255), # 노랑 -> ajour
    0: (0, 0, 0)      # 검정 -> background
}

def fill_unlabeled_areas_with(json_data, canvas_size):
    # 캔버스 생성 (검은색 배경: 0)
    image = np.zeros((canvas_size[1], canvas_size[0], 3), dtype=np.uint8)

    # 다각형 그리기
    for annotation in json_data["shapes"]:
        if annotation["label"] == "single_jersey":
            category_id = 1
        elif annotation["label"] == "rib":
            category_id = 2
        elif annotation["label"] == "purl":
            category_id = 3
        elif annotation["label"] == "interlock":
            category_id = 4
        elif annotation["label"] == "moss":
            category_id = 5
        elif annotation["label"] == "ajour":
            category_id = 6 
        else:
            continue  # 라벨이 없으면 skip
        
        polygon = annotation["points"]

        # 색상 선택
        color = category_colors.get(category_id, (255, 255, 255))  # 기본 색상은 흰색

        # 다각형 좌표를 픽셀 단위로 변환
        points = np.array([[int(x), int(y)] for x, y in polygon], dtype=np.int32)

        # 다각형 그리기
        cv2.polylines(image, [points], isClosed=True, color=color, thickness=2)
        cv2.fillPoly(image, [points], color=color)

    # 이미지 저장
    output_path = os.path.join(label_dir, f"annotated_{json_data['imagePath']}")
    cv2.imwrite(output_path, image)

# 파일 읽기 및 처리
for filename in os.listdir(DATA_DIR):
    if filename.endswith('.json'):  # .json 파일만 처리
        input_file_path = os.path.join(DATA_DIR, filename)
        
        # 파일을 ascii 인코딩으로 열기
        with open(input_file_path, 'r', encoding='ascii') as file:
            json_data = json.load(file)
        
        canvas_size = (json_data["imageWidth"], json_data["imageHeight"])
        fill_unlabeled_areas_with(json_data, canvas_size)

label_list = os.listdir(label_dir)
print(f"Number of annotated labels: {len(label_list)}")
# Out:
# Number of annotated labels: 192

# %% [markdown]
# 이미지 자르기 - 원본 이미지

# %%
import os
import cv2
import json

# 파일 이름에 따라 자를 방향 결정
top_cut_files = [
    10, 15, 16, 22, 28, 35, 37, 52, 59, 62, 63, 64, 74, 84, 88, 90,
    101, 107, 111, 120, 143, 148, 151, 157, 163, 166, 167, 168, 179,
    184, 186, 192, 200, 206, 219, 224, 230, 241, 242, 244, 268, 278
]
bottom_cut_files = [
    23, 26, 34, 43, 47, 49, 65, 73, 94, 93, 100, 109, 110, 112, 142,
    171, 172, 178, 181, 193, 195, 245, 251, 255, 275, 279, 293
]

# 이미지 폴더 경로 - 원본 이미지
image_dir = r"C:\Users\swu\Desktop\raw data"
crop_image_dir = r"C:\Users\swu\Desktop\raw data\crop_image"

# 크롭할 이미지 개수
DATA_NUM = 400 

# 크롭된 폴더가 없으면 생성
os.makedirs(crop_image_dir, exist_ok=True)

# 파일 이름 순서대로 반복
for i in range(1, DATA_NUM + 1):
    image_path = os.path.join(image_dir, f"{i}.jpg")

    # 이미지 파일이 없으면 건너뛰기
    if not os.path.exists(image_path):
        continue

    # 이미지 로드
    image = cv2.imread(image_path)

    if image is None:
        print(f"이미지를 찾을 수 없습니다: {image_path}")
        continue

    # 이미지 크기
    height, width, _ = image.shape

    # 정사각형 크기 결정 (가로와 세로 중 작은 값 선택)
    square_size = min(height, width)

    # 파일 이름에 따라 크롭 위치 결정
    if i in top_cut_files:
        start_x = (width - square_size) // 2
        start_y = 0
        end_x = start_x + square_size
        end_y = square_size
    elif i in bottom_cut_files:
        start_x = (width - square_size) // 2
        start_y = height - square_size
        end_x = start_x + square_size
        end_y = height
    else:
        start_x = (width - square_size) // 2
        start_y = (height - square_size) // 2
        end_x = start_x + square_size
        end_y = start_y + square_size

    # 이미지 크롭
    cropped_img = image[start_y:end_y, start_x:end_x]

    # 크롭된 이미지 저장
    output_image_name = f"{i}.jpg"
    output_image_path = os.path.join(crop_image_dir, output_image_name)
    cv2.imwrite(output_image_path, cropped_img)

    print(f"이미지 {i}: {output_image_name} 저장 완료")
# Out:
# 이미지 6: 6.jpg 저장 완료
# 이미지 7: 7.jpg 저장 완료
# 이미지 8: 8.jpg 저장 완료
# 이미지 9: 9.jpg 저장 완료
# 이미지 10: 10.jpg 저장 완료
# 이미지 11: 11.jpg 저장 완료
# 이미지 14: 14.jpg 저장 완료
# 이미지 15: 15.jpg 저장 완료
# 이미지 16: 16.jpg 저장 완료
# 이미지 17: 17.jpg 저장 완료
# 이미지 18: 18.jpg 저장 완료
# 이미지 19: 19.jpg 저장 완료
# 이미지 20: 20.jpg 저장 완료
# 이미지 21: 21.jpg 저장 완료
# 이미지 22: 22.jpg 저장 완료
# 이미지 23: 23.jpg 저장 완료
# 이미지 24: 24.jpg 저장 완료
# 이미지 26: 26.jpg 저장 완료
# 이미지 27: 27.jpg 저장 완료
# 이미지 28: 28.jpg 저장 완료
# 이미지 29: 29.jpg 저장 완료
# 이미지 33: 33.jpg 저장 완료
# 이미지 34: 34.jpg 저장 완료
# 이미지 35: 35.jpg 저장 완료
# 이미지 37: 37.jpg 저장 완료
# 이미지 38: 38.jpg 저장 완료
# 이미지 39: 39.jpg 저장 완료
# 이미지 40: 40.jpg 저장 완료
# 이미지 41: 41.jpg 저장 완료
# 이미지 42: 42.jpg 저장 완료
# 이미지 43: 43.jpg 저장 완료
# 이미지 45: 45.jpg 저장 완료
# 이미지 46: 46.jpg 저장 완료
# 이미지 47: 47.jpg 저장 완료
# 이미지 48: 48.jpg 저장 완료
# 이미지 49: 49.jpg 저장 완료
# 이미지 50: 50.jpg 저장 완료
# 이미지 51: 51.jpg 저장 완료
# 이미지 52: 52.jpg 저장 완료
# 이미지 53: 53.jpg 저장 완료
# 이미지 59: 59.jpg 저장 완료
# 이미지 60: 60.jpg 저장 완료
# 이미지 61: 61.jpg 저장 완료
# 이미지 62: 62.jpg 저장 완료
# 이미지 63: 63.jpg 저장 완료
# 이미지 64: 64.jpg 저장 완료
# 이미지 65: 65.jpg 저장 완료
# 이미지 66: 66.jpg 저장 완료
# 이미지 68: 68.jpg 저장 완료
# 이미지 69: 69.jpg 저장 완료
# 이미지 70: 70.jpg 저장 완료
# 이미지 71: 71.jpg 저장 완료
# 이미지 73: 73.jpg 저장 완료
# 이미지 74: 74.jpg 저장 완료
# 이미지 77: 77.jpg 저장 완료
# 이미지 78: 78.jpg 저장 완료
# 이미지 79: 79.jpg 저장 완료
# 이미지 80: 80.jpg 저장 완료
# 이미지 83: 83.jpg 저장 완료
# 이미지 84: 84.jpg 저장 완료
# 이미지 85: 85.jpg 저장 완료
# 이미지 86: 86.jpg 저장 완료
# 이미지 87: 87.jpg 저장 완료
# 이미지 88: 88.jpg 저장 완료
# 이미지 89: 89.jpg 저장 완료
# 이미지 90: 90.jpg 저장 완료
# 이미지 91: 91.jpg 저장 완료
# 이미지 92: 92.jpg 저장 완료
# 이미지 93: 93.jpg 저장 완료
# 이미지 94: 94.jpg 저장 완료
# 이미지 95: 95.jpg 저장 완료
# 이미지 99: 99.jpg 저장 완료
# 이미지 100: 100.jpg 저장 완료
# 이미지 101: 101.jpg 저장 완료
# 이미지 102: 102.jpg 저장 완료
# 이미지 103: 103.jpg 저장 완료
# 이미지 104: 104.jpg 저장 완료
# 이미지 105: 105.jpg 저장 완료
# 이미지 106: 106.jpg 저장 완료
# 이미지 107: 107.jpg 저장 완료
# 이미지 109: 109.jpg 저장 완료
# 이미지 110: 110.jpg 저장 완료
# 이미지 111: 111.jpg 저장 완료
# 이미지 112: 112.jpg 저장 완료
# 이미지 113: 113.jpg 저장 완료
# 이미지 114: 114.jpg 저장 완료
# 이미지 116: 116.jpg 저장 완료
# 이미지 118: 118.jpg 저장 완료
# 이미지 119: 119.jpg 저장 완료
# 이미지 120: 120.jpg 저장 완료
# 이미지 121: 121.jpg 저장 완료
# 이미지 122: 122.jpg 저장 완료
# 이미지 123: 123.jpg 저장 완료
# 이미지 124: 124.jpg 저장 완료
# 이미지 130: 130.jpg 저장 완료
# 이미지 132: 132.jpg 저장 완료
# 이미지 135: 135.jpg 저장 완료
# 이미지 137: 137.jpg 저장 완료
# 이미지 138: 138.jpg 저장 완료
# 이미지 139: 139.jpg 저장 완료
# 이미지 140: 140.jpg 저장 완료
# 이미지 141: 141.jpg 저장 완료
# 이미지 142: 142.jpg 저장 완료
# 이미지 143: 143.jpg 저장 완료
# 이미지 144: 144.jpg 저장 완료
# 이미지 147: 147.jpg 저장 완료
# 이미지 148: 148.jpg 저장 완료
# 이미지 150: 150.jpg 저장 완료
# 이미지 151: 151.jpg 저장 완료
# 이미지 153: 153.jpg 저장 완료
# 이미지 155: 155.jpg 저장 완료
# 이미지 156: 156.jpg 저장 완료
# 이미지 157: 157.jpg 저장 완료
# 이미지 163: 163.jpg 저장 완료
# 이미지 165: 165.jpg 저장 완료
# 이미지 166: 166.jpg 저장 완료
# 이미지 167: 167.jpg 저장 완료
# 이미지 168: 168.jpg 저장 완료
# 이미지 169: 169.jpg 저장 완료
# 이미지 171: 171.jpg 저장 완료
# 이미지 172: 172.jpg 저장 완료
# 이미지 174: 174.jpg 저장 완료
# 이미지 178: 178.jpg 저장 완료
# 이미지 179: 179.jpg 저장 완료
# 이미지 180: 180.jpg 저장 완료
# 이미지 181: 181.jpg 저장 완료
# 이미지 182: 182.jpg 저장 완료
# 이미지 184: 184.jpg 저장 완료
# 이미지 186: 186.jpg 저장 완료
# 이미지 188: 188.jpg 저장 완료
# 이미지 189: 189.jpg 저장 완료
# 이미지 192: 192.jpg 저장 완료
# 이미지 193: 193.jpg 저장 완료
# 이미지 194: 194.jpg 저장 완료
# 이미지 195: 195.jpg 저장 완료
# 이미지 196: 196.jpg 저장 완료
# 이미지 197: 197.jpg 저장 완료
# 이미지 199: 199.jpg 저장 완료
# 이미지 200: 200.jpg 저장 완료
# 이미지 205: 205.jpg 저장 완료
# 이미지 206: 206.jpg 저장 완료
# 이미지 208: 208.jpg 저장 완료
# 이미지 209: 209.jpg 저장 완료
# 이미지 211: 211.jpg 저장 완료
# 이미지 212: 212.jpg 저장 완료
# 이미지 213: 213.jpg 저장 완료
# 이미지 214: 214.jpg 저장 완료
# 이미지 215: 215.jpg 저장 완료
# 이미지 216: 216.jpg 저장 완료
# 이미지 219: 219.jpg 저장 완료
# 이미지 220: 220.jpg 저장 완료
# 이미지 224: 224.jpg 저장 완료
# 이미지 225: 225.jpg 저장 완료
# 이미지 227: 227.jpg 저장 완료
# 이미지 230: 230.jpg 저장 완료
# 이미지 231: 231.jpg 저장 완료
# 이미지 232: 232.jpg 저장 완료
# 이미지 233: 233.jpg 저장 완료
# 이미지 234: 234.jpg 저장 완료
# 이미지 236: 236.jpg 저장 완료
# 이미지 238: 238.jpg 저장 완료
# 이미지 240: 240.jpg 저장 완료
# 이미지 241: 241.jpg 저장 완료
# 이미지 242: 242.jpg 저장 완료
# 이미지 244: 244.jpg 저장 완료
# 이미지 245: 245.jpg 저장 완료
# 이미지 248: 248.jpg 저장 완료
# 이미지 251: 251.jpg 저장 완료
# 이미지 254: 254.jpg 저장 완료
# 이미지 255: 255.jpg 저장 완료
# 이미지 258: 258.jpg 저장 완료
# 이미지 264: 264.jpg 저장 완료
# 이미지 265: 265.jpg 저장 완료
# 이미지 268: 268.jpg 저장 완료
# 이미지 271: 271.jpg 저장 완료
# 이미지 272: 272.jpg 저장 완료
# 이미지 275: 275.jpg 저장 완료
# 이미지 277: 277.jpg 저장 완료
# 이미지 278: 278.jpg 저장 완료
# 이미지 279: 279.jpg 저장 완료
# 이미지 284: 284.jpg 저장 완료
# 이미지 288: 288.jpg 저장 완료
# 이미지 289: 289.jpg 저장 완료
# 이미지 291: 291.jpg 저장 완료
# 이미지 292: 292.jpg 저장 완료
# 이미지 293: 293.jpg 저장 완료
# 이미지 295: 295.jpg 저장 완료
# 이미지 296: 296.jpg 저장 완료
# 이미지 298: 298.jpg 저장 완료
# 이미지 300: 300.jpg 저장 완료
# 이미지 302: 302.jpg 저장 완료
# 이미지 305: 305.jpg 저장 완료

# %% [markdown]
# 이미지 자르기 - 라벨 이미지

# %%
import os
import cv2
import json

# 파일 이름에 따라 자를 방향 결정
top_cut_files = [
    10, 15, 16, 22, 28, 35, 37, 52, 59, 62, 63, 64, 74, 84, 88, 90,
    101, 107, 111, 120, 143, 148, 151, 157, 163, 166, 167, 168, 179,
    184, 186, 192, 200, 206, 219, 224, 230, 241, 242, 244, 268, 278
]
bottom_cut_files = [
    23, 26, 34, 43, 47, 49, 65, 73, 94, 93, 100, 109, 110, 112, 142,
    171, 172, 178, 181, 193, 195, 245, 251, 255, 275, 279, 293
]

# 이미지 폴더 경로 - 라벨 이미지
image_dir = r"C:\Users\swu\Desktop\raw data\label"
crop_image_dir = r"C:\Users\swu\Desktop\raw data\crop_label"

# 크롭할 이미지 개수
DATA_NUM = 400 

# 크롭된 폴더가 없으면 생성
os.makedirs(crop_image_dir, exist_ok=True)

# 파일 이름 순서대로 반복
for i in range(1, DATA_NUM + 1):
    image_path = os.path.join(image_dir, f"annotated_{i}.jpg")

    # 이미지 파일이 없으면 건너뛰기
    if not os.path.exists(image_path):
        continue

    # 이미지 로드
    image = cv2.imread(image_path)

    if image is None:
        print(f"이미지를 찾을 수 없습니다: {image_path}")
        continue

    # 이미지 크기
    height, width, _ = image.shape

    # 정사각형 크기 결정 (가로와 세로 중 작은 값 선택)
    square_size = min(height, width)

    # 파일 이름에 따라 크롭 위치 결정
    if i in top_cut_files:
        start_x = (width - square_size) // 2
        start_y = 0
        end_x = start_x + square_size
        end_y = square_size
    elif i in bottom_cut_files:
        start_x = (width - square_size) // 2
        start_y = height - square_size
        end_x = start_x + square_size
        end_y = height
    else:
        start_x = (width - square_size) // 2
        start_y = (height - square_size) // 2
        end_x = start_x + square_size
        end_y = start_y + square_size

    # 이미지 크롭
    cropped_img = image[start_y:end_y, start_x:end_x]

    # 크롭된 이미지 저장
    output_image_name = f"annoatated_{i}.jpg"
    output_image_path = os.path.join(crop_image_dir, output_image_name)
    cv2.imwrite(output_image_path, cropped_img)

    print(f"이미지 {i}: {output_image_name} 저장 완료")
# Out:
# 이미지 6: annoatated_6.jpg 저장 완료
# 이미지 7: annoatated_7.jpg 저장 완료
# 이미지 8: annoatated_8.jpg 저장 완료
# 이미지 9: annoatated_9.jpg 저장 완료
# 이미지 10: annoatated_10.jpg 저장 완료
# 이미지 11: annoatated_11.jpg 저장 완료
# 이미지 14: annoatated_14.jpg 저장 완료
# 이미지 15: annoatated_15.jpg 저장 완료
# 이미지 16: annoatated_16.jpg 저장 완료
# 이미지 17: annoatated_17.jpg 저장 완료
# 이미지 18: annoatated_18.jpg 저장 완료
# 이미지 19: annoatated_19.jpg 저장 완료
# 이미지 20: annoatated_20.jpg 저장 완료
# 이미지 21: annoatated_21.jpg 저장 완료
# 이미지 22: annoatated_22.jpg 저장 완료
# 이미지 23: annoatated_23.jpg 저장 완료
# 이미지 24: annoatated_24.jpg 저장 완료
# 이미지 26: annoatated_26.jpg 저장 완료
# 이미지 27: annoatated_27.jpg 저장 완료
# 이미지 28: annoatated_28.jpg 저장 완료
# 이미지 29: annoatated_29.jpg 저장 완료
# 이미지 33: annoatated_33.jpg 저장 완료
# 이미지 34: annoatated_34.jpg 저장 완료
# 이미지 35: annoatated_35.jpg 저장 완료
# 이미지 37: annoatated_37.jpg 저장 완료
# 이미지 38: annoatated_38.jpg 저장 완료
# 이미지 39: annoatated_39.jpg 저장 완료
# 이미지 40: annoatated_40.jpg 저장 완료
# 이미지 41: annoatated_41.jpg 저장 완료
# 이미지 42: annoatated_42.jpg 저장 완료
# 이미지 43: annoatated_43.jpg 저장 완료
# 이미지 45: annoatated_45.jpg 저장 완료
# 이미지 46: annoatated_46.jpg 저장 완료
# 이미지 47: annoatated_47.jpg 저장 완료
# 이미지 48: annoatated_48.jpg 저장 완료
# 이미지 49: annoatated_49.jpg 저장 완료
# 이미지 50: annoatated_50.jpg 저장 완료
# 이미지 51: annoatated_51.jpg 저장 완료
# 이미지 52: annoatated_52.jpg 저장 완료
# 이미지 53: annoatated_53.jpg 저장 완료
# 이미지 59: annoatated_59.jpg 저장 완료
# 이미지 60: annoatated_60.jpg 저장 완료
# 이미지 61: annoatated_61.jpg 저장 완료
# 이미지 62: annoatated_62.jpg 저장 완료
# 이미지 63: annoatated_63.jpg 저장 완료
# 이미지 64: annoatated_64.jpg 저장 완료
# 이미지 65: annoatated_65.jpg 저장 완료
# 이미지 66: annoatated_66.jpg 저장 완료
# 이미지 68: annoatated_68.jpg 저장 완료
# 이미지 69: annoatated_69.jpg 저장 완료
# 이미지 70: annoatated_70.jpg 저장 완료
# 이미지 71: annoatated_71.jpg 저장 완료
# 이미지 73: annoatated_73.jpg 저장 완료
# 이미지 74: annoatated_74.jpg 저장 완료
# 이미지 77: annoatated_77.jpg 저장 완료
# 이미지 78: annoatated_78.jpg 저장 완료
# 이미지 79: annoatated_79.jpg 저장 완료
# 이미지 80: annoatated_80.jpg 저장 완료
# 이미지 83: annoatated_83.jpg 저장 완료
# 이미지 84: annoatated_84.jpg 저장 완료
# 이미지 85: annoatated_85.jpg 저장 완료
# 이미지 86: annoatated_86.jpg 저장 완료
# 이미지 87: annoatated_87.jpg 저장 완료
# 이미지 88: annoatated_88.jpg 저장 완료
# 이미지 89: annoatated_89.jpg 저장 완료
# 이미지 90: annoatated_90.jpg 저장 완료
# 이미지 91: annoatated_91.jpg 저장 완료
# 이미지 92: annoatated_92.jpg 저장 완료
# 이미지 93: annoatated_93.jpg 저장 완료
# 이미지 94: annoatated_94.jpg 저장 완료
# 이미지 95: annoatated_95.jpg 저장 완료
# 이미지 99: annoatated_99.jpg 저장 완료
# 이미지 100: annoatated_100.jpg 저장 완료
# 이미지 101: annoatated_101.jpg 저장 완료
# 이미지 102: annoatated_102.jpg 저장 완료
# 이미지 103: annoatated_103.jpg 저장 완료
# 이미지 104: annoatated_104.jpg 저장 완료
# 이미지 105: annoatated_105.jpg 저장 완료
# 이미지 106: annoatated_106.jpg 저장 완료
# 이미지 107: annoatated_107.jpg 저장 완료
# 이미지 109: annoatated_109.jpg 저장 완료
# 이미지 110: annoatated_110.jpg 저장 완료
# 이미지 111: annoatated_111.jpg 저장 완료
# 이미지 112: annoatated_112.jpg 저장 완료
# 이미지 113: annoatated_113.jpg 저장 완료
# 이미지 114: annoatated_114.jpg 저장 완료
# 이미지 116: annoatated_116.jpg 저장 완료
# 이미지 118: annoatated_118.jpg 저장 완료
# 이미지 119: annoatated_119.jpg 저장 완료
# 이미지 120: annoatated_120.jpg 저장 완료
# 이미지 121: annoatated_121.jpg 저장 완료
# 이미지 122: annoatated_122.jpg 저장 완료
# 이미지 123: annoatated_123.jpg 저장 완료
# 이미지 124: annoatated_124.jpg 저장 완료
# 이미지 130: annoatated_130.jpg 저장 완료
# 이미지 132: annoatated_132.jpg 저장 완료
# 이미지 135: annoatated_135.jpg 저장 완료
# 이미지 137: annoatated_137.jpg 저장 완료
# 이미지 138: annoatated_138.jpg 저장 완료
# 이미지 139: annoatated_139.jpg 저장 완료
# 이미지 140: annoatated_140.jpg 저장 완료
# 이미지 141: annoatated_141.jpg 저장 완료
# 이미지 142: annoatated_142.jpg 저장 완료
# 이미지 143: annoatated_143.jpg 저장 완료
# 이미지 144: annoatated_144.jpg 저장 완료
# 이미지 147: annoatated_147.jpg 저장 완료
# 이미지 148: annoatated_148.jpg 저장 완료
# 이미지 150: annoatated_150.jpg 저장 완료
# 이미지 151: annoatated_151.jpg 저장 완료
# 이미지 153: annoatated_153.jpg 저장 완료
# 이미지 155: annoatated_155.jpg 저장 완료
# 이미지 156: annoatated_156.jpg 저장 완료
# 이미지 157: annoatated_157.jpg 저장 완료
# 이미지 163: annoatated_163.jpg 저장 완료
# 이미지 165: annoatated_165.jpg 저장 완료
# 이미지 166: annoatated_166.jpg 저장 완료
# 이미지 167: annoatated_167.jpg 저장 완료
# 이미지 168: annoatated_168.jpg 저장 완료
# 이미지 169: annoatated_169.jpg 저장 완료
# 이미지 171: annoatated_171.jpg 저장 완료
# 이미지 172: annoatated_172.jpg 저장 완료
# 이미지 174: annoatated_174.jpg 저장 완료
# 이미지 178: annoatated_178.jpg 저장 완료
# 이미지 179: annoatated_179.jpg 저장 완료
# 이미지 180: annoatated_180.jpg 저장 완료
# 이미지 181: annoatated_181.jpg 저장 완료
# 이미지 182: annoatated_182.jpg 저장 완료
# 이미지 184: annoatated_184.jpg 저장 완료
# 이미지 186: annoatated_186.jpg 저장 완료
# 이미지 188: annoatated_188.jpg 저장 완료
# 이미지 189: annoatated_189.jpg 저장 완료
# 이미지 192: annoatated_192.jpg 저장 완료
# 이미지 193: annoatated_193.jpg 저장 완료
# 이미지 194: annoatated_194.jpg 저장 완료
# 이미지 195: annoatated_195.jpg 저장 완료
# 이미지 196: annoatated_196.jpg 저장 완료
# 이미지 197: annoatated_197.jpg 저장 완료
# 이미지 199: annoatated_199.jpg 저장 완료
# 이미지 200: annoatated_200.jpg 저장 완료
# 이미지 205: annoatated_205.jpg 저장 완료
# 이미지 206: annoatated_206.jpg 저장 완료
# 이미지 208: annoatated_208.jpg 저장 완료
# 이미지 209: annoatated_209.jpg 저장 완료
# 이미지 211: annoatated_211.jpg 저장 완료
# 이미지 212: annoatated_212.jpg 저장 완료
# 이미지 213: annoatated_213.jpg 저장 완료
# 이미지 214: annoatated_214.jpg 저장 완료
# 이미지 215: annoatated_215.jpg 저장 완료
# 이미지 216: annoatated_216.jpg 저장 완료
# 이미지 219: annoatated_219.jpg 저장 완료
# 이미지 220: annoatated_220.jpg 저장 완료
# 이미지 224: annoatated_224.jpg 저장 완료
# 이미지 225: annoatated_225.jpg 저장 완료
# 이미지 227: annoatated_227.jpg 저장 완료
# 이미지 230: annoatated_230.jpg 저장 완료
# 이미지 231: annoatated_231.jpg 저장 완료
# 이미지 232: annoatated_232.jpg 저장 완료
# 이미지 233: annoatated_233.jpg 저장 완료
# 이미지 234: annoatated_234.jpg 저장 완료
# 이미지 236: annoatated_236.jpg 저장 완료
# 이미지 238: annoatated_238.jpg 저장 완료
# 이미지 240: annoatated_240.jpg 저장 완료
# 이미지 241: annoatated_241.jpg 저장 완료
# 이미지 242: annoatated_242.jpg 저장 완료
# 이미지 244: annoatated_244.jpg 저장 완료
# 이미지 245: annoatated_245.jpg 저장 완료
# 이미지 248: annoatated_248.jpg 저장 완료
# 이미지 251: annoatated_251.jpg 저장 완료
# 이미지 254: annoatated_254.jpg 저장 완료
# 이미지 255: annoatated_255.jpg 저장 완료
# 이미지 258: annoatated_258.jpg 저장 완료
# 이미지 264: annoatated_264.jpg 저장 완료
# 이미지 265: annoatated_265.jpg 저장 완료
# 이미지 268: annoatated_268.jpg 저장 완료
# 이미지 271: annoatated_271.jpg 저장 완료
# 이미지 272: annoatated_272.jpg 저장 완료
# 이미지 275: annoatated_275.jpg 저장 완료
# 이미지 277: annoatated_277.jpg 저장 완료
# 이미지 278: annoatated_278.jpg 저장 완료
# 이미지 279: annoatated_279.jpg 저장 완료
# 이미지 284: annoatated_284.jpg 저장 완료
# 이미지 288: annoatated_288.jpg 저장 완료
# 이미지 289: annoatated_289.jpg 저장 완료
# 이미지 291: annoatated_291.jpg 저장 완료
# 이미지 292: annoatated_292.jpg 저장 완료
# 이미지 293: annoatated_293.jpg 저장 완료
# 이미지 295: annoatated_295.jpg 저장 완료
# 이미지 296: annoatated_296.jpg 저장 완료
# 이미지 298: annoatated_298.jpg 저장 완료
# 이미지 300: annoatated_300.jpg 저장 완료
# 이미지 302: annoatated_302.jpg 저장 완료
# 이미지 305: annoatated_305.jpg 저장 완료

# %% [markdown]
# 파일명 정렬 (1부터) - 난 파일 라벨링 안 한 거 삭제해서 1부터 쭉 정렬함

# %%
import os
import shutil

# 원본 폴더 경로
crop_image_dir = r"C:\Users\swu\Desktop\raw data\crop_image"
crop_label_dir = r"C:\Users\swu\Desktop\raw data\crop_label"

# 새로운 저장 폴더 경로
num_crop_image_dir = r"C:\Users\swu\Desktop\raw data\crop_image_sort"
num_crop_label_dir = r"C:\Users\swu\Desktop\raw data\crop_label_sort"

# 폴더가 없으면 생성
os.makedirs(num_crop_image_dir, exist_ok=True)
os.makedirs(num_crop_label_dir, exist_ok=True)

# 이미지 파일 및 라벨 파일 리스트 가져오기
image_files = sorted([f for f in os.listdir(crop_image_dir) if f.endswith('.jpg')])
label_files = sorted([f for f in os.listdir(crop_label_dir) if f.endswith('.jpg')])

# 이미지 파일 리네이밍 및 저장
for idx, image_file in enumerate(image_files, 1):
    # 새로운 파일 이름 생성
    new_image_name = f"{idx}.jpg"
    
    # 원본 이미지 경로
    old_image_path = os.path.join(crop_image_dir, image_file)
    # 새로운 이미지 경로
    new_image_path = os.path.join(num_crop_image_dir, new_image_name)
    
    # 이미지 파일 이동
    shutil.copy(old_image_path, new_image_path)
    print(f"'{image_file}' -> '{new_image_name}' (num_crop_image)")

# 라벨 파일 리네이밍 및 저장
for idx, label_file in enumerate(label_files, 1):
    # 새로운 파일 이름 생성
    new_label_name = f"annotated_{idx}.jpg"
    
    # 원본 라벨 경로
    old_label_path = os.path.join(crop_label_dir, label_file)
    # 새로운 라벨 경로
    new_label_path = os.path.join(num_crop_label_dir, new_label_name)
    
    # 라벨 파일 이동
    shutil.copy(old_label_path, new_label_path)
    print(f"'{label_file}' -> '{new_label_name}' (num_crop_label)")
# Out:
# '10.jpg' -> '1.jpg' (num_crop_image)
# '100.jpg' -> '2.jpg' (num_crop_image)
# '101.jpg' -> '3.jpg' (num_crop_image)
# '102.jpg' -> '4.jpg' (num_crop_image)
# '103.jpg' -> '5.jpg' (num_crop_image)
# '104.jpg' -> '6.jpg' (num_crop_image)
# '105.jpg' -> '7.jpg' (num_crop_image)
# '106.jpg' -> '8.jpg' (num_crop_image)
# '107.jpg' -> '9.jpg' (num_crop_image)
# '109.jpg' -> '10.jpg' (num_crop_image)
# '11.jpg' -> '11.jpg' (num_crop_image)
# '110.jpg' -> '12.jpg' (num_crop_image)
# '111.jpg' -> '13.jpg' (num_crop_image)
# '112.jpg' -> '14.jpg' (num_crop_image)
# '113.jpg' -> '15.jpg' (num_crop_image)
# '114.jpg' -> '16.jpg' (num_crop_image)
# '116.jpg' -> '17.jpg' (num_crop_image)
# '118.jpg' -> '18.jpg' (num_crop_image)
# '119.jpg' -> '19.jpg' (num_crop_image)
# '120.jpg' -> '20.jpg' (num_crop_image)
# '121.jpg' -> '21.jpg' (num_crop_image)
# '122.jpg' -> '22.jpg' (num_crop_image)
# '123.jpg' -> '23.jpg' (num_crop_image)
# '124.jpg' -> '24.jpg' (num_crop_image)
# '130.jpg' -> '25.jpg' (num_crop_image)
# '132.jpg' -> '26.jpg' (num_crop_image)
# '135.jpg' -> '27.jpg' (num_crop_image)
# '137.jpg' -> '28.jpg' (num_crop_image)
# '138.jpg' -> '29.jpg' (num_crop_image)
# '139.jpg' -> '30.jpg' (num_crop_image)
# '14.jpg' -> '31.jpg' (num_crop_image)
# '140.jpg' -> '32.jpg' (num_crop_image)
# '141.jpg' -> '33.jpg' (num_crop_image)
# '142.jpg' -> '34.jpg' (num_crop_image)
# '143.jpg' -> '35.jpg' (num_crop_image)
# '144.jpg' -> '36.jpg' (num_crop_image)
# '147.jpg' -> '37.jpg' (num_crop_image)
# '148.jpg' -> '38.jpg' (num_crop_image)
# '15.jpg' -> '39.jpg' (num_crop_image)
# '150.jpg' -> '40.jpg' (num_crop_image)
# '151.jpg' -> '41.jpg' (num_crop_image)
# '153.jpg' -> '42.jpg' (num_crop_image)
# '155.jpg' -> '43.jpg' (num_crop_image)
# '156.jpg' -> '44.jpg' (num_crop_image)
# '157.jpg' -> '45.jpg' (num_crop_image)
# '16.jpg' -> '46.jpg' (num_crop_image)
# '163.jpg' -> '47.jpg' (num_crop_image)
# '165.jpg' -> '48.jpg' (num_crop_image)
# '166.jpg' -> '49.jpg' (num_crop_image)
# '167.jpg' -> '50.jpg' (num_crop_image)
# '168.jpg' -> '51.jpg' (num_crop_image)
# '169.jpg' -> '52.jpg' (num_crop_image)
# '17.jpg' -> '53.jpg' (num_crop_image)
# '171.jpg' -> '54.jpg' (num_crop_image)
# '172.jpg' -> '55.jpg' (num_crop_image)
# '174.jpg' -> '56.jpg' (num_crop_image)
# '178.jpg' -> '57.jpg' (num_crop_image)
# '179.jpg' -> '58.jpg' (num_crop_image)
# '18.jpg' -> '59.jpg' (num_crop_image)
# '180.jpg' -> '60.jpg' (num_crop_image)
# '181.jpg' -> '61.jpg' (num_crop_image)
# '182.jpg' -> '62.jpg' (num_crop_image)
# '184.jpg' -> '63.jpg' (num_crop_image)
# '186.jpg' -> '64.jpg' (num_crop_image)
# '188.jpg' -> '65.jpg' (num_crop_image)
# '189.jpg' -> '66.jpg' (num_crop_image)
# '19.jpg' -> '67.jpg' (num_crop_image)
# '192.jpg' -> '68.jpg' (num_crop_image)
# '193.jpg' -> '69.jpg' (num_crop_image)
# '194.jpg' -> '70.jpg' (num_crop_image)
# '195.jpg' -> '71.jpg' (num_crop_image)
# '196.jpg' -> '72.jpg' (num_crop_image)
# '197.jpg' -> '73.jpg' (num_crop_image)
# '199.jpg' -> '74.jpg' (num_crop_image)
# '20.jpg' -> '75.jpg' (num_crop_image)
# '200.jpg' -> '76.jpg' (num_crop_image)
# '205.jpg' -> '77.jpg' (num_crop_image)
# '206.jpg' -> '78.jpg' (num_crop_image)
# '208.jpg' -> '79.jpg' (num_crop_image)
# '209.jpg' -> '80.jpg' (num_crop_image)
# '21.jpg' -> '81.jpg' (num_crop_image)
# '211.jpg' -> '82.jpg' (num_crop_image)
# '212.jpg' -> '83.jpg' (num_crop_image)
# '213.jpg' -> '84.jpg' (num_crop_image)
# '214.jpg' -> '85.jpg' (num_crop_image)
# '215.jpg' -> '86.jpg' (num_crop_image)
# '216.jpg' -> '87.jpg' (num_crop_image)
# '219.jpg' -> '88.jpg' (num_crop_image)
# '22.jpg' -> '89.jpg' (num_crop_image)
# '220.jpg' -> '90.jpg' (num_crop_image)
# '224.jpg' -> '91.jpg' (num_crop_image)
# '225.jpg' -> '92.jpg' (num_crop_image)
# '227.jpg' -> '93.jpg' (num_crop_image)
# '23.jpg' -> '94.jpg' (num_crop_image)
# '230.jpg' -> '95.jpg' (num_crop_image)
# '231.jpg' -> '96.jpg' (num_crop_image)
# '232.jpg' -> '97.jpg' (num_crop_image)
# '233.jpg' -> '98.jpg' (num_crop_image)
# '234.jpg' -> '99.jpg' (num_crop_image)
# '236.jpg' -> '100.jpg' (num_crop_image)
# '238.jpg' -> '101.jpg' (num_crop_image)
# '24.jpg' -> '102.jpg' (num_crop_image)
# '240.jpg' -> '103.jpg' (num_crop_image)
# '241.jpg' -> '104.jpg' (num_crop_image)
# '242.jpg' -> '105.jpg' (num_crop_image)
# '244.jpg' -> '106.jpg' (num_crop_image)
# '245.jpg' -> '107.jpg' (num_crop_image)
# '248.jpg' -> '108.jpg' (num_crop_image)
# '251.jpg' -> '109.jpg' (num_crop_image)
# '254.jpg' -> '110.jpg' (num_crop_image)
# '255.jpg' -> '111.jpg' (num_crop_image)
# '258.jpg' -> '112.jpg' (num_crop_image)
# '26.jpg' -> '113.jpg' (num_crop_image)
# '264.jpg' -> '114.jpg' (num_crop_image)
# '265.jpg' -> '115.jpg' (num_crop_image)
# '268.jpg' -> '116.jpg' (num_crop_image)
# '27.jpg' -> '117.jpg' (num_crop_image)
# '271.jpg' -> '118.jpg' (num_crop_image)
# '272.jpg' -> '119.jpg' (num_crop_image)
# '275.jpg' -> '120.jpg' (num_crop_image)
# '277.jpg' -> '121.jpg' (num_crop_image)
# '278.jpg' -> '122.jpg' (num_crop_image)
# '279.jpg' -> '123.jpg' (num_crop_image)
# '28.jpg' -> '124.jpg' (num_crop_image)
# '284.jpg' -> '125.jpg' (num_crop_image)
# '288.jpg' -> '126.jpg' (num_crop_image)
# '289.jpg' -> '127.jpg' (num_crop_image)
# '29.jpg' -> '128.jpg' (num_crop_image)
# '291.jpg' -> '129.jpg' (num_crop_image)
# '292.jpg' -> '130.jpg' (num_crop_image)
# '293.jpg' -> '131.jpg' (num_crop_image)
# '295.jpg' -> '132.jpg' (num_crop_image)
# '296.jpg' -> '133.jpg' (num_crop_image)
# '298.jpg' -> '134.jpg' (num_crop_image)
# '300.jpg' -> '135.jpg' (num_crop_image)
# '302.jpg' -> '136.jpg' (num_crop_image)
# '305.jpg' -> '137.jpg' (num_crop_image)
# '33.jpg' -> '138.jpg' (num_crop_image)
# '34.jpg' -> '139.jpg' (num_crop_image)
# '35.jpg' -> '140.jpg' (num_crop_image)
# '37.jpg' -> '141.jpg' (num_crop_image)
# '38.jpg' -> '142.jpg' (num_crop_image)
# '39.jpg' -> '143.jpg' (num_crop_image)
# '40.jpg' -> '144.jpg' (num_crop_image)
# '41.jpg' -> '145.jpg' (num_crop_image)
# '42.jpg' -> '146.jpg' (num_crop_image)
# '43.jpg' -> '147.jpg' (num_crop_image)
# '45.jpg' -> '148.jpg' (num_crop_image)
# '46.jpg' -> '149.jpg' (num_crop_image)
# '47.jpg' -> '150.jpg' (num_crop_image)
# '48.jpg' -> '151.jpg' (num_crop_image)
# '49.jpg' -> '152.jpg' (num_crop_image)
# '50.jpg' -> '153.jpg' (num_crop_image)
# '51.jpg' -> '154.jpg' (num_crop_image)
# '52.jpg' -> '155.jpg' (num_crop_image)
# '53.jpg' -> '156.jpg' (num_crop_image)
# '59.jpg' -> '157.jpg' (num_crop_image)
# '6.jpg' -> '158.jpg' (num_crop_image)
# '60.jpg' -> '159.jpg' (num_crop_image)
# '61.jpg' -> '160.jpg' (num_crop_image)
# '62.jpg' -> '161.jpg' (num_crop_image)
# '63.jpg' -> '162.jpg' (num_crop_image)
# '64.jpg' -> '163.jpg' (num_crop_image)
# '65.jpg' -> '164.jpg' (num_crop_image)
# '66.jpg' -> '165.jpg' (num_crop_image)
# '68.jpg' -> '166.jpg' (num_crop_image)
# '69.jpg' -> '167.jpg' (num_crop_image)
# '7.jpg' -> '168.jpg' (num_crop_image)
# '70.jpg' -> '169.jpg' (num_crop_image)
# '71.jpg' -> '170.jpg' (num_crop_image)
# '73.jpg' -> '171.jpg' (num_crop_image)
# '74.jpg' -> '172.jpg' (num_crop_image)
# '77.jpg' -> '173.jpg' (num_crop_image)
# '78.jpg' -> '174.jpg' (num_crop_image)
# '79.jpg' -> '175.jpg' (num_crop_image)
# '8.jpg' -> '176.jpg' (num_crop_image)
# '80.jpg' -> '177.jpg' (num_crop_image)
# '83.jpg' -> '178.jpg' (num_crop_image)
# '84.jpg' -> '179.jpg' (num_crop_image)
# '85.jpg' -> '180.jpg' (num_crop_image)
# '86.jpg' -> '181.jpg' (num_crop_image)
# '87.jpg' -> '182.jpg' (num_crop_image)
# '88.jpg' -> '183.jpg' (num_crop_image)
# '89.jpg' -> '184.jpg' (num_crop_image)
# '9.jpg' -> '185.jpg' (num_crop_image)
# '90.jpg' -> '186.jpg' (num_crop_image)
# '91.jpg' -> '187.jpg' (num_crop_image)
# '92.jpg' -> '188.jpg' (num_crop_image)
# '93.jpg' -> '189.jpg' (num_crop_image)
# '94.jpg' -> '190.jpg' (num_crop_image)
# '95.jpg' -> '191.jpg' (num_crop_image)
# '99.jpg' -> '192.jpg' (num_crop_image)
# 'annoatated_10.jpg' -> 'annotated_1.jpg' (num_crop_label)
# 'annoatated_100.jpg' -> 'annotated_2.jpg' (num_crop_label)
# 'annoatated_101.jpg' -> 'annotated_3.jpg' (num_crop_label)
# 'annoatated_102.jpg' -> 'annotated_4.jpg' (num_crop_label)
# 'annoatated_103.jpg' -> 'annotated_5.jpg' (num_crop_label)
# 'annoatated_104.jpg' -> 'annotated_6.jpg' (num_crop_label)
# 'annoatated_105.jpg' -> 'annotated_7.jpg' (num_crop_label)
# 'annoatated_106.jpg' -> 'annotated_8.jpg' (num_crop_label)
# 'annoatated_107.jpg' -> 'annotated_9.jpg' (num_crop_label)
# 'annoatated_109.jpg' -> 'annotated_10.jpg' (num_crop_label)
# 'annoatated_11.jpg' -> 'annotated_11.jpg' (num_crop_label)
# 'annoatated_110.jpg' -> 'annotated_12.jpg' (num_crop_label)
# 'annoatated_111.jpg' -> 'annotated_13.jpg' (num_crop_label)
# 'annoatated_112.jpg' -> 'annotated_14.jpg' (num_crop_label)
# 'annoatated_113.jpg' -> 'annotated_15.jpg' (num_crop_label)
# 'annoatated_114.jpg' -> 'annotated_16.jpg' (num_crop_label)
# 'annoatated_116.jpg' -> 'annotated_17.jpg' (num_crop_label)
# 'annoatated_118.jpg' -> 'annotated_18.jpg' (num_crop_label)
# 'annoatated_119.jpg' -> 'annotated_19.jpg' (num_crop_label)
# 'annoatated_120.jpg' -> 'annotated_20.jpg' (num_crop_label)
# 'annoatated_121.jpg' -> 'annotated_21.jpg' (num_crop_label)
# 'annoatated_122.jpg' -> 'annotated_22.jpg' (num_crop_label)
# 'annoatated_123.jpg' -> 'annotated_23.jpg' (num_crop_label)
# 'annoatated_124.jpg' -> 'annotated_24.jpg' (num_crop_label)
# 'annoatated_130.jpg' -> 'annotated_25.jpg' (num_crop_label)
# 'annoatated_132.jpg' -> 'annotated_26.jpg' (num_crop_label)
# 'annoatated_135.jpg' -> 'annotated_27.jpg' (num_crop_label)
# 'annoatated_137.jpg' -> 'annotated_28.jpg' (num_crop_label)
# 'annoatated_138.jpg' -> 'annotated_29.jpg' (num_crop_label)
# 'annoatated_139.jpg' -> 'annotated_30.jpg' (num_crop_label)
# 'annoatated_14.jpg' -> 'annotated_31.jpg' (num_crop_label)
# 'annoatated_140.jpg' -> 'annotated_32.jpg' (num_crop_label)
# 'annoatated_141.jpg' -> 'annotated_33.jpg' (num_crop_label)
# 'annoatated_142.jpg' -> 'annotated_34.jpg' (num_crop_label)
# 'annoatated_143.jpg' -> 'annotated_35.jpg' (num_crop_label)
# 'annoatated_144.jpg' -> 'annotated_36.jpg' (num_crop_label)
# 'annoatated_147.jpg' -> 'annotated_37.jpg' (num_crop_label)
# 'annoatated_148.jpg' -> 'annotated_38.jpg' (num_crop_label)
# 'annoatated_15.jpg' -> 'annotated_39.jpg' (num_crop_label)
# 'annoatated_150.jpg' -> 'annotated_40.jpg' (num_crop_label)
# 'annoatated_151.jpg' -> 'annotated_41.jpg' (num_crop_label)
# 'annoatated_153.jpg' -> 'annotated_42.jpg' (num_crop_label)
# 'annoatated_155.jpg' -> 'annotated_43.jpg' (num_crop_label)
# 'annoatated_156.jpg' -> 'annotated_44.jpg' (num_crop_label)
# 'annoatated_157.jpg' -> 'annotated_45.jpg' (num_crop_label)
# 'annoatated_16.jpg' -> 'annotated_46.jpg' (num_crop_label)
# 'annoatated_163.jpg' -> 'annotated_47.jpg' (num_crop_label)
# 'annoatated_165.jpg' -> 'annotated_48.jpg' (num_crop_label)
# 'annoatated_166.jpg' -> 'annotated_49.jpg' (num_crop_label)
# 'annoatated_167.jpg' -> 'annotated_50.jpg' (num_crop_label)
# 'annoatated_168.jpg' -> 'annotated_51.jpg' (num_crop_label)
# 'annoatated_169.jpg' -> 'annotated_52.jpg' (num_crop_label)
# 'annoatated_17.jpg' -> 'annotated_53.jpg' (num_crop_label)
# 'annoatated_171.jpg' -> 'annotated_54.jpg' (num_crop_label)
# 'annoatated_172.jpg' -> 'annotated_55.jpg' (num_crop_label)
# 'annoatated_174.jpg' -> 'annotated_56.jpg' (num_crop_label)
# 'annoatated_178.jpg' -> 'annotated_57.jpg' (num_crop_label)
# 'annoatated_179.jpg' -> 'annotated_58.jpg' (num_crop_label)
# 'annoatated_18.jpg' -> 'annotated_59.jpg' (num_crop_label)
# 'annoatated_180.jpg' -> 'annotated_60.jpg' (num_crop_label)
# 'annoatated_181.jpg' -> 'annotated_61.jpg' (num_crop_label)
# 'annoatated_182.jpg' -> 'annotated_62.jpg' (num_crop_label)
# 'annoatated_184.jpg' -> 'annotated_63.jpg' (num_crop_label)
# 'annoatated_186.jpg' -> 'annotated_64.jpg' (num_crop_label)
# 'annoatated_188.jpg' -> 'annotated_65.jpg' (num_crop_label)
# 'annoatated_189.jpg' -> 'annotated_66.jpg' (num_crop_label)
# 'annoatated_19.jpg' -> 'annotated_67.jpg' (num_crop_label)
# 'annoatated_192.jpg' -> 'annotated_68.jpg' (num_crop_label)
# 'annoatated_193.jpg' -> 'annotated_69.jpg' (num_crop_label)
# 'annoatated_194.jpg' -> 'annotated_70.jpg' (num_crop_label)
# 'annoatated_195.jpg' -> 'annotated_71.jpg' (num_crop_label)
# 'annoatated_196.jpg' -> 'annotated_72.jpg' (num_crop_label)
# 'annoatated_197.jpg' -> 'annotated_73.jpg' (num_crop_label)
# 'annoatated_199.jpg' -> 'annotated_74.jpg' (num_crop_label)
# 'annoatated_20.jpg' -> 'annotated_75.jpg' (num_crop_label)
# 'annoatated_200.jpg' -> 'annotated_76.jpg' (num_crop_label)
# 'annoatated_205.jpg' -> 'annotated_77.jpg' (num_crop_label)
# 'annoatated_206.jpg' -> 'annotated_78.jpg' (num_crop_label)
# 'annoatated_208.jpg' -> 'annotated_79.jpg' (num_crop_label)
# 'annoatated_209.jpg' -> 'annotated_80.jpg' (num_crop_label)
# 'annoatated_21.jpg' -> 'annotated_81.jpg' (num_crop_label)
# 'annoatated_211.jpg' -> 'annotated_82.jpg' (num_crop_label)
# 'annoatated_212.jpg' -> 'annotated_83.jpg' (num_crop_label)
# 'annoatated_213.jpg' -> 'annotated_84.jpg' (num_crop_label)
# 'annoatated_214.jpg' -> 'annotated_85.jpg' (num_crop_label)
# 'annoatated_215.jpg' -> 'annotated_86.jpg' (num_crop_label)
# 'annoatated_216.jpg' -> 'annotated_87.jpg' (num_crop_label)
# 'annoatated_219.jpg' -> 'annotated_88.jpg' (num_crop_label)
# 'annoatated_22.jpg' -> 'annotated_89.jpg' (num_crop_label)
# 'annoatated_220.jpg' -> 'annotated_90.jpg' (num_crop_label)
# 'annoatated_224.jpg' -> 'annotated_91.jpg' (num_crop_label)
# 'annoatated_225.jpg' -> 'annotated_92.jpg' (num_crop_label)
# 'annoatated_227.jpg' -> 'annotated_93.jpg' (num_crop_label)
# 'annoatated_23.jpg' -> 'annotated_94.jpg' (num_crop_label)
# 'annoatated_230.jpg' -> 'annotated_95.jpg' (num_crop_label)
# 'annoatated_231.jpg' -> 'annotated_96.jpg' (num_crop_label)
# 'annoatated_232.jpg' -> 'annotated_97.jpg' (num_crop_label)
# 'annoatated_233.jpg' -> 'annotated_98.jpg' (num_crop_label)
# 'annoatated_234.jpg' -> 'annotated_99.jpg' (num_crop_label)
# 'annoatated_236.jpg' -> 'annotated_100.jpg' (num_crop_label)
# 'annoatated_238.jpg' -> 'annotated_101.jpg' (num_crop_label)
# 'annoatated_24.jpg' -> 'annotated_102.jpg' (num_crop_label)
# 'annoatated_240.jpg' -> 'annotated_103.jpg' (num_crop_label)
# 'annoatated_241.jpg' -> 'annotated_104.jpg' (num_crop_label)
# 'annoatated_242.jpg' -> 'annotated_105.jpg' (num_crop_label)
# 'annoatated_244.jpg' -> 'annotated_106.jpg' (num_crop_label)
# 'annoatated_245.jpg' -> 'annotated_107.jpg' (num_crop_label)
# 'annoatated_248.jpg' -> 'annotated_108.jpg' (num_crop_label)
# 'annoatated_251.jpg' -> 'annotated_109.jpg' (num_crop_label)
# 'annoatated_254.jpg' -> 'annotated_110.jpg' (num_crop_label)
# 'annoatated_255.jpg' -> 'annotated_111.jpg' (num_crop_label)
# 'annoatated_258.jpg' -> 'annotated_112.jpg' (num_crop_label)
# 'annoatated_26.jpg' -> 'annotated_113.jpg' (num_crop_label)
# 'annoatated_264.jpg' -> 'annotated_114.jpg' (num_crop_label)
# 'annoatated_265.jpg' -> 'annotated_115.jpg' (num_crop_label)
# 'annoatated_268.jpg' -> 'annotated_116.jpg' (num_crop_label)
# 'annoatated_27.jpg' -> 'annotated_117.jpg' (num_crop_label)
# 'annoatated_271.jpg' -> 'annotated_118.jpg' (num_crop_label)
# 'annoatated_272.jpg' -> 'annotated_119.jpg' (num_crop_label)
# 'annoatated_275.jpg' -> 'annotated_120.jpg' (num_crop_label)
# 'annoatated_277.jpg' -> 'annotated_121.jpg' (num_crop_label)
# 'annoatated_278.jpg' -> 'annotated_122.jpg' (num_crop_label)
# 'annoatated_279.jpg' -> 'annotated_123.jpg' (num_crop_label)
# 'annoatated_28.jpg' -> 'annotated_124.jpg' (num_crop_label)
# 'annoatated_284.jpg' -> 'annotated_125.jpg' (num_crop_label)
# 'annoatated_288.jpg' -> 'annotated_126.jpg' (num_crop_label)
# 'annoatated_289.jpg' -> 'annotated_127.jpg' (num_crop_label)
# 'annoatated_29.jpg' -> 'annotated_128.jpg' (num_crop_label)
# 'annoatated_291.jpg' -> 'annotated_129.jpg' (num_crop_label)
# 'annoatated_292.jpg' -> 'annotated_130.jpg' (num_crop_label)
# 'annoatated_293.jpg' -> 'annotated_131.jpg' (num_crop_label)
# 'annoatated_295.jpg' -> 'annotated_132.jpg' (num_crop_label)
# 'annoatated_296.jpg' -> 'annotated_133.jpg' (num_crop_label)
# 'annoatated_298.jpg' -> 'annotated_134.jpg' (num_crop_label)
# 'annoatated_300.jpg' -> 'annotated_135.jpg' (num_crop_label)
# 'annoatated_302.jpg' -> 'annotated_136.jpg' (num_crop_label)
# 'annoatated_305.jpg' -> 'annotated_137.jpg' (num_crop_label)
# 'annoatated_33.jpg' -> 'annotated_138.jpg' (num_crop_label)
# 'annoatated_34.jpg' -> 'annotated_139.jpg' (num_crop_label)
# 'annoatated_35.jpg' -> 'annotated_140.jpg' (num_crop_label)
# 'annoatated_37.jpg' -> 'annotated_141.jpg' (num_crop_label)
# 'annoatated_38.jpg' -> 'annotated_142.jpg' (num_crop_label)
# 'annoatated_39.jpg' -> 'annotated_143.jpg' (num_crop_label)
# 'annoatated_40.jpg' -> 'annotated_144.jpg' (num_crop_label)
# 'annoatated_41.jpg' -> 'annotated_145.jpg' (num_crop_label)
# 'annoatated_42.jpg' -> 'annotated_146.jpg' (num_crop_label)
# 'annoatated_43.jpg' -> 'annotated_147.jpg' (num_crop_label)
# 'annoatated_45.jpg' -> 'annotated_148.jpg' (num_crop_label)
# 'annoatated_46.jpg' -> 'annotated_149.jpg' (num_crop_label)
# 'annoatated_47.jpg' -> 'annotated_150.jpg' (num_crop_label)
# 'annoatated_48.jpg' -> 'annotated_151.jpg' (num_crop_label)
# 'annoatated_49.jpg' -> 'annotated_152.jpg' (num_crop_label)
# 'annoatated_50.jpg' -> 'annotated_153.jpg' (num_crop_label)
# 'annoatated_51.jpg' -> 'annotated_154.jpg' (num_crop_label)
# 'annoatated_52.jpg' -> 'annotated_155.jpg' (num_crop_label)
# 'annoatated_53.jpg' -> 'annotated_156.jpg' (num_crop_label)
# 'annoatated_59.jpg' -> 'annotated_157.jpg' (num_crop_label)
# 'annoatated_6.jpg' -> 'annotated_158.jpg' (num_crop_label)
# 'annoatated_60.jpg' -> 'annotated_159.jpg' (num_crop_label)
# 'annoatated_61.jpg' -> 'annotated_160.jpg' (num_crop_label)
# 'annoatated_62.jpg' -> 'annotated_161.jpg' (num_crop_label)
# 'annoatated_63.jpg' -> 'annotated_162.jpg' (num_crop_label)
# 'annoatated_64.jpg' -> 'annotated_163.jpg' (num_crop_label)
# 'annoatated_65.jpg' -> 'annotated_164.jpg' (num_crop_label)
# 'annoatated_66.jpg' -> 'annotated_165.jpg' (num_crop_label)
# 'annoatated_68.jpg' -> 'annotated_166.jpg' (num_crop_label)
# 'annoatated_69.jpg' -> 'annotated_167.jpg' (num_crop_label)
# 'annoatated_7.jpg' -> 'annotated_168.jpg' (num_crop_label)
# 'annoatated_70.jpg' -> 'annotated_169.jpg' (num_crop_label)
# 'annoatated_71.jpg' -> 'annotated_170.jpg' (num_crop_label)
# 'annoatated_73.jpg' -> 'annotated_171.jpg' (num_crop_label)
# 'annoatated_74.jpg' -> 'annotated_172.jpg' (num_crop_label)
# 'annoatated_77.jpg' -> 'annotated_173.jpg' (num_crop_label)
# 'annoatated_78.jpg' -> 'annotated_174.jpg' (num_crop_label)
# 'annoatated_79.jpg' -> 'annotated_175.jpg' (num_crop_label)
# 'annoatated_8.jpg' -> 'annotated_176.jpg' (num_crop_label)
# 'annoatated_80.jpg' -> 'annotated_177.jpg' (num_crop_label)
# 'annoatated_83.jpg' -> 'annotated_178.jpg' (num_crop_label)
# 'annoatated_84.jpg' -> 'annotated_179.jpg' (num_crop_label)
# 'annoatated_85.jpg' -> 'annotated_180.jpg' (num_crop_label)
# 'annoatated_86.jpg' -> 'annotated_181.jpg' (num_crop_label)
# 'annoatated_87.jpg' -> 'annotated_182.jpg' (num_crop_label)
# 'annoatated_88.jpg' -> 'annotated_183.jpg' (num_crop_label)
# 'annoatated_89.jpg' -> 'annotated_184.jpg' (num_crop_label)
# 'annoatated_9.jpg' -> 'annotated_185.jpg' (num_crop_label)
# 'annoatated_90.jpg' -> 'annotated_186.jpg' (num_crop_label)
# 'annoatated_91.jpg' -> 'annotated_187.jpg' (num_crop_label)
# 'annoatated_92.jpg' -> 'annotated_188.jpg' (num_crop_label)
# 'annoatated_93.jpg' -> 'annotated_189.jpg' (num_crop_label)
# 'annoatated_94.jpg' -> 'annotated_190.jpg' (num_crop_label)
# 'annoatated_95.jpg' -> 'annotated_191.jpg' (num_crop_label)
# 'annoatated_99.jpg' -> 'annotated_192.jpg' (num_crop_label)

# %% [markdown]
# 데이터 증폭

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 데이터 경로
data_path = r'C:\Users\swu\Desktop\final data test'  # 데이터 경로
input_path = os.path.join(data_path, "image")
label_path = os.path.join(data_path, "label")
output_path_inputs = os.path.join(data_path, "augmented", "image")
output_path_labels = os.path.join(data_path, "augmented", "label")

# 출력 폴더
os.makedirs(output_path_inputs, exist_ok=True)
os.makedirs(output_path_labels, exist_ok=True)

input_files = sorted([os.path.join(input_path, f) for f in os.listdir(input_path) if f.endswith('.jpg')])
label_files = sorted([os.path.join(label_path, f) for f in os.listdir(label_path) if f.endswith('.jpg')])

# 데이터 증폭 설정
data_gen_args = dict(
    rotation_range=360,         # 랜덤 회전 범위
    width_shift_range=0.2,      # 가로 이동 범위
    height_shift_range=0.2,     # 세로 이동 범위
    shear_range=0.2,            # 기울이기 범위
    horizontal_flip=True,       # 좌우 반전
    fill_mode='constant',       # 빈 부분 채우기
    cval=0                      # 채운 값 (검은색으로 채우기)
)

# ImageDataGenerator 생성
image_datagen = ImageDataGenerator(**data_gen_args)
label_datagen = ImageDataGenerator(**data_gen_args)

# 랜덤 색 변환 함수
def random_color_transform(image, hue_shift, sat_shift, val_shift):
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)  # BGR -> HSV
    hsv_image[..., 0] = (hsv_image[..., 0] + hue_shift) % 180  # Hue 변경
    hsv_image[..., 1] = np.clip(hsv_image[..., 1] * sat_shift, 0, 255)  # Saturation 변경
    hsv_image[..., 2] = np.clip(hsv_image[..., 2] * val_shift, 0, 255)  # Brightness 변경
    return cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)  # HSV -> BGR

# 증폭 시작
num_augmentations_per_image = 10  # 각 이미지당 생성할 데이터 수

for idx, (input_file, label_file) in enumerate(zip(input_files, label_files)):
    input_img = cv2.imread(input_file)
    label_img = cv2.imread(label_file)

    # 256x256으로 이미지 크기 조정
    input_img = cv2.resize(input_img, (256, 256))
    label_img = cv2.resize(label_img, (256, 256))

    input_img = np.expand_dims(input_img, 0)  # 배치 차원 추가
    label_img = np.expand_dims(label_img, 0)  # 배치 차원 추가

    input_gen = image_datagen.flow(input_img, batch_size=1, seed=42)
    label_gen = label_datagen.flow(label_img, batch_size=1, seed=42)

    for aug_idx in range(num_augmentations_per_image):
        aug_input = input_gen.next()[0].astype(np.uint8)
        aug_label = label_gen.next()[0].astype(np.uint8)

        # 색 변환 (밝기와 대비 완화)
        hue_shift = np.random.randint(0, 180)
        sat_shift = np.random.uniform(0.8, 1.2)  # 대비 범위 줄임
        val_shift = np.random.uniform(0.8, 1.2)  # 밝기 범위 줄임

        aug_input = random_color_transform(aug_input, hue_shift, sat_shift, val_shift)

        # 이미지 파일 번호 설정
        img_num = idx * 10 + aug_idx + 193  # 시작 번호 설정

        # 파일 경로 설정
        input_output_file = os.path.join(output_path_inputs, f'{img_num}.jpg')
        label_output_file = os.path.join(output_path_labels, f'annotated_{img_num}.jpg')

        # 이미지 저장
        cv2.imwrite(input_output_file, aug_input)
        cv2.imwrite(label_output_file, aug_label)

print(f"총 {len(input_files) * num_augmentations_per_image}개의 데이터 증폭 완료")
# Out:
# 총 1920개의 데이터 증폭 완료

# %% [markdown]
# 파일명 정렬 (자기 순서에 맞게)

# %%
import os
import shutil

# 원본 폴더 경로
crop_image_dir = r"C:\Users\swu\Desktop\Data\Preprocessing\final data\augmented\image"
crop_label_dir = r"C:\Users\swu\Desktop\Data\Preprocessing\final data\augmented\label"

# 새로운 저장 폴더 경로
num_crop_image_dir = r"C:\Users\swu\Desktop\Data\Preprocessing\final data\augmented\image_sorted"
num_crop_label_dir = r"C:\Users\swu\Desktop\Data\Preprocessing\final data\augmented\label_sorted"

# 폴더가 없으면 생성
os.makedirs(num_crop_image_dir, exist_ok=True)
os.makedirs(num_crop_label_dir, exist_ok=True)

# 이미지 파일 및 라벨 파일 리스트 가져오기
image_files = sorted([f for f in os.listdir(crop_image_dir) if f.endswith('.jpg')])
label_files = sorted([f for f in os.listdir(crop_label_dir) if f.endswith('.jpg')])

# 이미지 파일 리네이밍 및 저장
for idx, image_file in enumerate(image_files, 2051): ## 여기 수정
    # 새로운 파일 이름 생성
    new_image_name = f"{idx}.jpg"
    
    # 원본 이미지 경로
    old_image_path = os.path.join(crop_image_dir, image_file)
    # 새로운 이미지 경로
    new_image_path = os.path.join(num_crop_image_dir, new_image_name)
    
    # 이미지 파일 이동
    shutil.copy(old_image_path, new_image_path)
    print(f"'{image_file}' -> '{new_image_name}' (num_crop_image)")

# 라벨 파일 리네이밍 및 저장
for idx, label_file in enumerate(label_files, 2051):
    # 새로운 파일 이름 생성
    new_label_name = f"annotated_{idx}.jpg"
    
    # 원본 라벨 경로
    old_label_path = os.path.join(crop_label_dir, label_file)
    # 새로운 라벨 경로
    new_label_path = os.path.join(num_crop_label_dir, new_label_name)
    
    # 라벨 파일 이동
    shutil.copy(old_label_path, new_label_path)
    print(f"'{label_file}' -> '{new_label_name}' (num_crop_label)")
# Out:
# '1000.jpg' -> '2051.jpg' (num_crop_image)
# '1001.jpg' -> '2052.jpg' (num_crop_image)
# '1002.jpg' -> '2053.jpg' (num_crop_image)
# '1003.jpg' -> '2054.jpg' (num_crop_image)
# '1004.jpg' -> '2055.jpg' (num_crop_image)
# '1005.jpg' -> '2056.jpg' (num_crop_image)
# '1006.jpg' -> '2057.jpg' (num_crop_image)
# '1007.jpg' -> '2058.jpg' (num_crop_image)
# '1008.jpg' -> '2059.jpg' (num_crop_image)
# '1009.jpg' -> '2060.jpg' (num_crop_image)
# '1010.jpg' -> '2061.jpg' (num_crop_image)
# '1011.jpg' -> '2062.jpg' (num_crop_image)
# '1012.jpg' -> '2063.jpg' (num_crop_image)
# '1013.jpg' -> '2064.jpg' (num_crop_image)
# '1014.jpg' -> '2065.jpg' (num_crop_image)
# '1015.jpg' -> '2066.jpg' (num_crop_image)
# '1016.jpg' -> '2067.jpg' (num_crop_image)
# '1017.jpg' -> '2068.jpg' (num_crop_image)
# '1018.jpg' -> '2069.jpg' (num_crop_image)
# '1019.jpg' -> '2070.jpg' (num_crop_image)
# '1020.jpg' -> '2071.jpg' (num_crop_image)
# '1021.jpg' -> '2072.jpg' (num_crop_image)
# '1022.jpg' -> '2073.jpg' (num_crop_image)
# '1023.jpg' -> '2074.jpg' (num_crop_image)
# '1024.jpg' -> '2075.jpg' (num_crop_image)
# '1025.jpg' -> '2076.jpg' (num_crop_image)
# '1026.jpg' -> '2077.jpg' (num_crop_image)
# '1027.jpg' -> '2078.jpg' (num_crop_image)
# '1028.jpg' -> '2079.jpg' (num_crop_image)
# '1029.jpg' -> '2080.jpg' (num_crop_image)
# '1030.jpg' -> '2081.jpg' (num_crop_image)
# '1031.jpg' -> '2082.jpg' (num_crop_image)
# '1032.jpg' -> '2083.jpg' (num_crop_image)
# '1033.jpg' -> '2084.jpg' (num_crop_image)
# '1034.jpg' -> '2085.jpg' (num_crop_image)
# '1035.jpg' -> '2086.jpg' (num_crop_image)
# '1036.jpg' -> '2087.jpg' (num_crop_image)
# '1037.jpg' -> '2088.jpg' (num_crop_image)
# '1038.jpg' -> '2089.jpg' (num_crop_image)
# '1039.jpg' -> '2090.jpg' (num_crop_image)
# '1040.jpg' -> '2091.jpg' (num_crop_image)
# '1041.jpg' -> '2092.jpg' (num_crop_image)
# '1042.jpg' -> '2093.jpg' (num_crop_image)
# '1043.jpg' -> '2094.jpg' (num_crop_image)
# '1044.jpg' -> '2095.jpg' (num_crop_image)
# '1045.jpg' -> '2096.jpg' (num_crop_image)
# '1046.jpg' -> '2097.jpg' (num_crop_image)
# '1047.jpg' -> '2098.jpg' (num_crop_image)
# '1048.jpg' -> '2099.jpg' (num_crop_image)
# '1049.jpg' -> '2100.jpg' (num_crop_image)
# '1050.jpg' -> '2101.jpg' (num_crop_image)
# '1051.jpg' -> '2102.jpg' (num_crop_image)
# '1052.jpg' -> '2103.jpg' (num_crop_image)
# '1053.jpg' -> '2104.jpg' (num_crop_image)
# '1054.jpg' -> '2105.jpg' (num_crop_image)
# '1055.jpg' -> '2106.jpg' (num_crop_image)
# '1056.jpg' -> '2107.jpg' (num_crop_image)
# '1057.jpg' -> '2108.jpg' (num_crop_image)
# '1058.jpg' -> '2109.jpg' (num_crop_image)
# '1059.jpg' -> '2110.jpg' (num_crop_image)
# '1060.jpg' -> '2111.jpg' (num_crop_image)
# '1061.jpg' -> '2112.jpg' (num_crop_image)
# '1062.jpg' -> '2113.jpg' (num_crop_image)
# '1063.jpg' -> '2114.jpg' (num_crop_image)
# '1064.jpg' -> '2115.jpg' (num_crop_image)
# '1065.jpg' -> '2116.jpg' (num_crop_image)
# '1066.jpg' -> '2117.jpg' (num_crop_image)
# '1067.jpg' -> '2118.jpg' (num_crop_image)
# '1068.jpg' -> '2119.jpg' (num_crop_image)
# '1069.jpg' -> '2120.jpg' (num_crop_image)
# '1070.jpg' -> '2121.jpg' (num_crop_image)
# '1071.jpg' -> '2122.jpg' (num_crop_image)
# '1072.jpg' -> '2123.jpg' (num_crop_image)
# '1073.jpg' -> '2124.jpg' (num_crop_image)
# '1074.jpg' -> '2125.jpg' (num_crop_image)
# '1075.jpg' -> '2126.jpg' (num_crop_image)
# '1076.jpg' -> '2127.jpg' (num_crop_image)
# '1077.jpg' -> '2128.jpg' (num_crop_image)
# '1078.jpg' -> '2129.jpg' (num_crop_image)
# '1079.jpg' -> '2130.jpg' (num_crop_image)
# '1080.jpg' -> '2131.jpg' (num_crop_image)
# '1081.jpg' -> '2132.jpg' (num_crop_image)
# '1082.jpg' -> '2133.jpg' (num_crop_image)
# '1083.jpg' -> '2134.jpg' (num_crop_image)
# '1084.jpg' -> '2135.jpg' (num_crop_image)
# '1085.jpg' -> '2136.jpg' (num_crop_image)
# '1086.jpg' -> '2137.jpg' (num_crop_image)
# '1087.jpg' -> '2138.jpg' (num_crop_image)
# '1088.jpg' -> '2139.jpg' (num_crop_image)
# '1089.jpg' -> '2140.jpg' (num_crop_image)
# '1090.jpg' -> '2141.jpg' (num_crop_image)
# '1091.jpg' -> '2142.jpg' (num_crop_image)
# '1092.jpg' -> '2143.jpg' (num_crop_image)
# '1093.jpg' -> '2144.jpg' (num_crop_image)
# '1094.jpg' -> '2145.jpg' (num_crop_image)
# '1095.jpg' -> '2146.jpg' (num_crop_image)
# '1096.jpg' -> '2147.jpg' (num_crop_image)
# '1097.jpg' -> '2148.jpg' (num_crop_image)
# '1098.jpg' -> '2149.jpg' (num_crop_image)
# '1099.jpg' -> '2150.jpg' (num_crop_image)
# '1100.jpg' -> '2151.jpg' (num_crop_image)
# '1101.jpg' -> '2152.jpg' (num_crop_image)
# '1102.jpg' -> '2153.jpg' (num_crop_image)
# '1103.jpg' -> '2154.jpg' (num_crop_image)
# '1104.jpg' -> '2155.jpg' (num_crop_image)
# '1105.jpg' -> '2156.jpg' (num_crop_image)
# '1106.jpg' -> '2157.jpg' (num_crop_image)
# '1107.jpg' -> '2158.jpg' (num_crop_image)
# '1108.jpg' -> '2159.jpg' (num_crop_image)
# '1109.jpg' -> '2160.jpg' (num_crop_image)
# '1110.jpg' -> '2161.jpg' (num_crop_image)
# '1111.jpg' -> '2162.jpg' (num_crop_image)
# '1112.jpg' -> '2163.jpg' (num_crop_image)
# '1113.jpg' -> '2164.jpg' (num_crop_image)
# '1114.jpg' -> '2165.jpg' (num_crop_image)
# '1115.jpg' -> '2166.jpg' (num_crop_image)
# '1116.jpg' -> '2167.jpg' (num_crop_image)
# '1117.jpg' -> '2168.jpg' (num_crop_image)
# '1118.jpg' -> '2169.jpg' (num_crop_image)
# '1119.jpg' -> '2170.jpg' (num_crop_image)
# '1120.jpg' -> '2171.jpg' (num_crop_image)
# '1121.jpg' -> '2172.jpg' (num_crop_image)
# '1122.jpg' -> '2173.jpg' (num_crop_image)
# '1123.jpg' -> '2174.jpg' (num_crop_image)
# '1124.jpg' -> '2175.jpg' (num_crop_image)
# '1125.jpg' -> '2176.jpg' (num_crop_image)
# '1126.jpg' -> '2177.jpg' (num_crop_image)
# '1127.jpg' -> '2178.jpg' (num_crop_image)
# '1128.jpg' -> '2179.jpg' (num_crop_image)
# '1129.jpg' -> '2180.jpg' (num_crop_image)
# '1130.jpg' -> '2181.jpg' (num_crop_image)
# '1131.jpg' -> '2182.jpg' (num_crop_image)
# '1132.jpg' -> '2183.jpg' (num_crop_image)
# '1133.jpg' -> '2184.jpg' (num_crop_image)
# '1134.jpg' -> '2185.jpg' (num_crop_image)
# '1135.jpg' -> '2186.jpg' (num_crop_image)
# '1136.jpg' -> '2187.jpg' (num_crop_image)
# '1137.jpg' -> '2188.jpg' (num_crop_image)
# '1138.jpg' -> '2189.jpg' (num_crop_image)
# '1139.jpg' -> '2190.jpg' (num_crop_image)
# '1140.jpg' -> '2191.jpg' (num_crop_image)
# '1141.jpg' -> '2192.jpg' (num_crop_image)
# '1142.jpg' -> '2193.jpg' (num_crop_image)
# '1143.jpg' -> '2194.jpg' (num_crop_image)
# '1144.jpg' -> '2195.jpg' (num_crop_image)
# '1145.jpg' -> '2196.jpg' (num_crop_image)
# '1146.jpg' -> '2197.jpg' (num_crop_image)
# '1147.jpg' -> '2198.jpg' (num_crop_image)
# '1148.jpg' -> '2199.jpg' (num_crop_image)
# '1149.jpg' -> '2200.jpg' (num_crop_image)
# '1150.jpg' -> '2201.jpg' (num_crop_image)
# '1151.jpg' -> '2202.jpg' (num_crop_image)
# '1152.jpg' -> '2203.jpg' (num_crop_image)
# '1153.jpg' -> '2204.jpg' (num_crop_image)
# '1154.jpg' -> '2205.jpg' (num_crop_image)
# '1155.jpg' -> '2206.jpg' (num_crop_image)
# '1156.jpg' -> '2207.jpg' (num_crop_image)
# '1157.jpg' -> '2208.jpg' (num_crop_image)
# '1158.jpg' -> '2209.jpg' (num_crop_image)
# '1159.jpg' -> '2210.jpg' (num_crop_image)
# '1160.jpg' -> '2211.jpg' (num_crop_image)
# '1161.jpg' -> '2212.jpg' (num_crop_image)
# '1162.jpg' -> '2213.jpg' (num_crop_image)
# '1163.jpg' -> '2214.jpg' (num_crop_image)
# '1164.jpg' -> '2215.jpg' (num_crop_image)
# '1165.jpg' -> '2216.jpg' (num_crop_image)
# '1166.jpg' -> '2217.jpg' (num_crop_image)
# '1167.jpg' -> '2218.jpg' (num_crop_image)
# '1168.jpg' -> '2219.jpg' (num_crop_image)
# '1169.jpg' -> '2220.jpg' (num_crop_image)
# '1170.jpg' -> '2221.jpg' (num_crop_image)
# '1171.jpg' -> '2222.jpg' (num_crop_image)
# '1172.jpg' -> '2223.jpg' (num_crop_image)
# '1173.jpg' -> '2224.jpg' (num_crop_image)
# '1174.jpg' -> '2225.jpg' (num_crop_image)
# '1175.jpg' -> '2226.jpg' (num_crop_image)
# '1176.jpg' -> '2227.jpg' (num_crop_image)
# '1177.jpg' -> '2228.jpg' (num_crop_image)
# '1178.jpg' -> '2229.jpg' (num_crop_image)
# '1179.jpg' -> '2230.jpg' (num_crop_image)
# '1180.jpg' -> '2231.jpg' (num_crop_image)
# '1181.jpg' -> '2232.jpg' (num_crop_image)
# '1182.jpg' -> '2233.jpg' (num_crop_image)
# '1183.jpg' -> '2234.jpg' (num_crop_image)
# '1184.jpg' -> '2235.jpg' (num_crop_image)
# '1185.jpg' -> '2236.jpg' (num_crop_image)
# '1186.jpg' -> '2237.jpg' (num_crop_image)
# '1187.jpg' -> '2238.jpg' (num_crop_image)
# '1188.jpg' -> '2239.jpg' (num_crop_image)
# '1189.jpg' -> '2240.jpg' (num_crop_image)
# '1190.jpg' -> '2241.jpg' (num_crop_image)
# '1191.jpg' -> '2242.jpg' (num_crop_image)
# '1192.jpg' -> '2243.jpg' (num_crop_image)
# '1193.jpg' -> '2244.jpg' (num_crop_image)
# '1194.jpg' -> '2245.jpg' (num_crop_image)
# '1195.jpg' -> '2246.jpg' (num_crop_image)
# '1196.jpg' -> '2247.jpg' (num_crop_image)
# '1197.jpg' -> '2248.jpg' (num_crop_image)
# '1198.jpg' -> '2249.jpg' (num_crop_image)
# '1199.jpg' -> '2250.jpg' (num_crop_image)
# '1200.jpg' -> '2251.jpg' (num_crop_image)
# '1201.jpg' -> '2252.jpg' (num_crop_image)
# '1202.jpg' -> '2253.jpg' (num_crop_image)
# '1203.jpg' -> '2254.jpg' (num_crop_image)
# '1204.jpg' -> '2255.jpg' (num_crop_image)
# '1205.jpg' -> '2256.jpg' (num_crop_image)
# '1206.jpg' -> '2257.jpg' (num_crop_image)
# '1207.jpg' -> '2258.jpg' (num_crop_image)
# '1208.jpg' -> '2259.jpg' (num_crop_image)
# '1209.jpg' -> '2260.jpg' (num_crop_image)
# '1210.jpg' -> '2261.jpg' (num_crop_image)
# '1211.jpg' -> '2262.jpg' (num_crop_image)
# '1212.jpg' -> '2263.jpg' (num_crop_image)
# '1213.jpg' -> '2264.jpg' (num_crop_image)
# '1214.jpg' -> '2265.jpg' (num_crop_image)
# '1215.jpg' -> '2266.jpg' (num_crop_image)
# '1216.jpg' -> '2267.jpg' (num_crop_image)
# '1217.jpg' -> '2268.jpg' (num_crop_image)
# '1218.jpg' -> '2269.jpg' (num_crop_image)
# '1219.jpg' -> '2270.jpg' (num_crop_image)
# '1220.jpg' -> '2271.jpg' (num_crop_image)
# '1221.jpg' -> '2272.jpg' (num_crop_image)
# '1222.jpg' -> '2273.jpg' (num_crop_image)
# '1223.jpg' -> '2274.jpg' (num_crop_image)
# '1224.jpg' -> '2275.jpg' (num_crop_image)
# '1225.jpg' -> '2276.jpg' (num_crop_image)
# '1226.jpg' -> '2277.jpg' (num_crop_image)
# '1227.jpg' -> '2278.jpg' (num_crop_image)
# '1228.jpg' -> '2279.jpg' (num_crop_image)
# '1229.jpg' -> '2280.jpg' (num_crop_image)
# '1230.jpg' -> '2281.jpg' (num_crop_image)
# '1231.jpg' -> '2282.jpg' (num_crop_image)
# '1232.jpg' -> '2283.jpg' (num_crop_image)
# '1233.jpg' -> '2284.jpg' (num_crop_image)
# '1234.jpg' -> '2285.jpg' (num_crop_image)
# '1235.jpg' -> '2286.jpg' (num_crop_image)
# '1236.jpg' -> '2287.jpg' (num_crop_image)
# '1237.jpg' -> '2288.jpg' (num_crop_image)
# '1238.jpg' -> '2289.jpg' (num_crop_image)
# '1239.jpg' -> '2290.jpg' (num_crop_image)
# '1240.jpg' -> '2291.jpg' (num_crop_image)
# '1241.jpg' -> '2292.jpg' (num_crop_image)
# '1242.jpg' -> '2293.jpg' (num_crop_image)
# '1243.jpg' -> '2294.jpg' (num_crop_image)
# '1244.jpg' -> '2295.jpg' (num_crop_image)
# '1245.jpg' -> '2296.jpg' (num_crop_image)
# '1246.jpg' -> '2297.jpg' (num_crop_image)
# '1247.jpg' -> '2298.jpg' (num_crop_image)
# '1248.jpg' -> '2299.jpg' (num_crop_image)
# '1249.jpg' -> '2300.jpg' (num_crop_image)
# '1250.jpg' -> '2301.jpg' (num_crop_image)
# '1251.jpg' -> '2302.jpg' (num_crop_image)
# '1252.jpg' -> '2303.jpg' (num_crop_image)
# '1253.jpg' -> '2304.jpg' (num_crop_image)
# '1254.jpg' -> '2305.jpg' (num_crop_image)
# '1255.jpg' -> '2306.jpg' (num_crop_image)
# '1256.jpg' -> '2307.jpg' (num_crop_image)
# '1257.jpg' -> '2308.jpg' (num_crop_image)
# '1258.jpg' -> '2309.jpg' (num_crop_image)
# '1259.jpg' -> '2310.jpg' (num_crop_image)
# '1260.jpg' -> '2311.jpg' (num_crop_image)
# '1261.jpg' -> '2312.jpg' (num_crop_image)
# '1262.jpg' -> '2313.jpg' (num_crop_image)
# '1263.jpg' -> '2314.jpg' (num_crop_image)
# '1264.jpg' -> '2315.jpg' (num_crop_image)
# '1265.jpg' -> '2316.jpg' (num_crop_image)
# '1266.jpg' -> '2317.jpg' (num_crop_image)
# '1267.jpg' -> '2318.jpg' (num_crop_image)
# '1268.jpg' -> '2319.jpg' (num_crop_image)
# '1269.jpg' -> '2320.jpg' (num_crop_image)
# '1270.jpg' -> '2321.jpg' (num_crop_image)
# '1271.jpg' -> '2322.jpg' (num_crop_image)
# '1272.jpg' -> '2323.jpg' (num_crop_image)
# '1273.jpg' -> '2324.jpg' (num_crop_image)
# '1274.jpg' -> '2325.jpg' (num_crop_image)
# '1275.jpg' -> '2326.jpg' (num_crop_image)
# '1276.jpg' -> '2327.jpg' (num_crop_image)
# '1277.jpg' -> '2328.jpg' (num_crop_image)
# '1278.jpg' -> '2329.jpg' (num_crop_image)
# '1279.jpg' -> '2330.jpg' (num_crop_image)
# '1280.jpg' -> '2331.jpg' (num_crop_image)
# '1281.jpg' -> '2332.jpg' (num_crop_image)
# '1282.jpg' -> '2333.jpg' (num_crop_image)
# '1283.jpg' -> '2334.jpg' (num_crop_image)
# '1284.jpg' -> '2335.jpg' (num_crop_image)
# '1285.jpg' -> '2336.jpg' (num_crop_image)
# '1286.jpg' -> '2337.jpg' (num_crop_image)
# '1287.jpg' -> '2338.jpg' (num_crop_image)
# '1288.jpg' -> '2339.jpg' (num_crop_image)
# '1289.jpg' -> '2340.jpg' (num_crop_image)
# '1290.jpg' -> '2341.jpg' (num_crop_image)
# '1291.jpg' -> '2342.jpg' (num_crop_image)
# '1292.jpg' -> '2343.jpg' (num_crop_image)
# '1293.jpg' -> '2344.jpg' (num_crop_image)
# '1294.jpg' -> '2345.jpg' (num_crop_image)
# '1295.jpg' -> '2346.jpg' (num_crop_image)
# '1296.jpg' -> '2347.jpg' (num_crop_image)
# '1297.jpg' -> '2348.jpg' (num_crop_image)
# '1298.jpg' -> '2349.jpg' (num_crop_image)
# '1299.jpg' -> '2350.jpg' (num_crop_image)
# '1300.jpg' -> '2351.jpg' (num_crop_image)
# '1301.jpg' -> '2352.jpg' (num_crop_image)
# '1302.jpg' -> '2353.jpg' (num_crop_image)
# '1303.jpg' -> '2354.jpg' (num_crop_image)
# '1304.jpg' -> '2355.jpg' (num_crop_image)
# '1305.jpg' -> '2356.jpg' (num_crop_image)
# '1306.jpg' -> '2357.jpg' (num_crop_image)
# '1307.jpg' -> '2358.jpg' (num_crop_image)
# '1308.jpg' -> '2359.jpg' (num_crop_image)
# '1309.jpg' -> '2360.jpg' (num_crop_image)
# '1310.jpg' -> '2361.jpg' (num_crop_image)
# '1311.jpg' -> '2362.jpg' (num_crop_image)
# '1312.jpg' -> '2363.jpg' (num_crop_image)
# '1313.jpg' -> '2364.jpg' (num_crop_image)
# '1314.jpg' -> '2365.jpg' (num_crop_image)
# '1315.jpg' -> '2366.jpg' (num_crop_image)
# '1316.jpg' -> '2367.jpg' (num_crop_image)
# '1317.jpg' -> '2368.jpg' (num_crop_image)
# '1318.jpg' -> '2369.jpg' (num_crop_image)
# '1319.jpg' -> '2370.jpg' (num_crop_image)
# '1320.jpg' -> '2371.jpg' (num_crop_image)
# '1321.jpg' -> '2372.jpg' (num_crop_image)
# '1322.jpg' -> '2373.jpg' (num_crop_image)
# '1323.jpg' -> '2374.jpg' (num_crop_image)
# '1324.jpg' -> '2375.jpg' (num_crop_image)
# '1325.jpg' -> '2376.jpg' (num_crop_image)
# '1326.jpg' -> '2377.jpg' (num_crop_image)
# '1327.jpg' -> '2378.jpg' (num_crop_image)
# '1328.jpg' -> '2379.jpg' (num_crop_image)
# '1329.jpg' -> '2380.jpg' (num_crop_image)
# '1330.jpg' -> '2381.jpg' (num_crop_image)
# '1331.jpg' -> '2382.jpg' (num_crop_image)
# '1332.jpg' -> '2383.jpg' (num_crop_image)
# '1333.jpg' -> '2384.jpg' (num_crop_image)
# '1334.jpg' -> '2385.jpg' (num_crop_image)
# '1335.jpg' -> '2386.jpg' (num_crop_image)
# '1336.jpg' -> '2387.jpg' (num_crop_image)
# '1337.jpg' -> '2388.jpg' (num_crop_image)
# '1338.jpg' -> '2389.jpg' (num_crop_image)
# '1339.jpg' -> '2390.jpg' (num_crop_image)
# '1340.jpg' -> '2391.jpg' (num_crop_image)
# '1341.jpg' -> '2392.jpg' (num_crop_image)
# '1342.jpg' -> '2393.jpg' (num_crop_image)
# '1343.jpg' -> '2394.jpg' (num_crop_image)
# '1344.jpg' -> '2395.jpg' (num_crop_image)
# '1345.jpg' -> '2396.jpg' (num_crop_image)
# '1346.jpg' -> '2397.jpg' (num_crop_image)
# '1347.jpg' -> '2398.jpg' (num_crop_image)
# '1348.jpg' -> '2399.jpg' (num_crop_image)
# '1349.jpg' -> '2400.jpg' (num_crop_image)
# '1350.jpg' -> '2401.jpg' (num_crop_image)
# '1351.jpg' -> '2402.jpg' (num_crop_image)
# '1352.jpg' -> '2403.jpg' (num_crop_image)
# '1353.jpg' -> '2404.jpg' (num_crop_image)
# '1354.jpg' -> '2405.jpg' (num_crop_image)
# '1355.jpg' -> '2406.jpg' (num_crop_image)
# '1356.jpg' -> '2407.jpg' (num_crop_image)
# '1357.jpg' -> '2408.jpg' (num_crop_image)
# '1358.jpg' -> '2409.jpg' (num_crop_image)
# '1359.jpg' -> '2410.jpg' (num_crop_image)
# '1360.jpg' -> '2411.jpg' (num_crop_image)
# '1361.jpg' -> '2412.jpg' (num_crop_image)
# '1362.jpg' -> '2413.jpg' (num_crop_image)
# '1363.jpg' -> '2414.jpg' (num_crop_image)
# '1364.jpg' -> '2415.jpg' (num_crop_image)
# '1365.jpg' -> '2416.jpg' (num_crop_image)
# '1366.jpg' -> '2417.jpg' (num_crop_image)
# '1367.jpg' -> '2418.jpg' (num_crop_image)
# '1368.jpg' -> '2419.jpg' (num_crop_image)
# '1369.jpg' -> '2420.jpg' (num_crop_image)
# '1370.jpg' -> '2421.jpg' (num_crop_image)
# '1371.jpg' -> '2422.jpg' (num_crop_image)
# '1372.jpg' -> '2423.jpg' (num_crop_image)
# '1373.jpg' -> '2424.jpg' (num_crop_image)
# '1374.jpg' -> '2425.jpg' (num_crop_image)
# '1375.jpg' -> '2426.jpg' (num_crop_image)
# '1376.jpg' -> '2427.jpg' (num_crop_image)
# '1377.jpg' -> '2428.jpg' (num_crop_image)
# '1378.jpg' -> '2429.jpg' (num_crop_image)
# '1379.jpg' -> '2430.jpg' (num_crop_image)
# '1380.jpg' -> '2431.jpg' (num_crop_image)
# '1381.jpg' -> '2432.jpg' (num_crop_image)
# '1382.jpg' -> '2433.jpg' (num_crop_image)
# '1383.jpg' -> '2434.jpg' (num_crop_image)
# '1384.jpg' -> '2435.jpg' (num_crop_image)
# '1385.jpg' -> '2436.jpg' (num_crop_image)
# '1386.jpg' -> '2437.jpg' (num_crop_image)
# '1387.jpg' -> '2438.jpg' (num_crop_image)
# '1388.jpg' -> '2439.jpg' (num_crop_image)
# '1389.jpg' -> '2440.jpg' (num_crop_image)
# '1390.jpg' -> '2441.jpg' (num_crop_image)
# '1391.jpg' -> '2442.jpg' (num_crop_image)
# '1392.jpg' -> '2443.jpg' (num_crop_image)
# '1393.jpg' -> '2444.jpg' (num_crop_image)
# '1394.jpg' -> '2445.jpg' (num_crop_image)
# '1395.jpg' -> '2446.jpg' (num_crop_image)
# '1396.jpg' -> '2447.jpg' (num_crop_image)
# '1397.jpg' -> '2448.jpg' (num_crop_image)
# '1398.jpg' -> '2449.jpg' (num_crop_image)
# '1399.jpg' -> '2450.jpg' (num_crop_image)
# '1400.jpg' -> '2451.jpg' (num_crop_image)
# '1401.jpg' -> '2452.jpg' (num_crop_image)
# '1402.jpg' -> '2453.jpg' (num_crop_image)
# '1403.jpg' -> '2454.jpg' (num_crop_image)
# '1404.jpg' -> '2455.jpg' (num_crop_image)
# '1405.jpg' -> '2456.jpg' (num_crop_image)
# '1406.jpg' -> '2457.jpg' (num_crop_image)
# '1407.jpg' -> '2458.jpg' (num_crop_image)
# '1408.jpg' -> '2459.jpg' (num_crop_image)
# '1409.jpg' -> '2460.jpg' (num_crop_image)
# '1410.jpg' -> '2461.jpg' (num_crop_image)
# '1411.jpg' -> '2462.jpg' (num_crop_image)
# '1412.jpg' -> '2463.jpg' (num_crop_image)
# '1413.jpg' -> '2464.jpg' (num_crop_image)
# '1414.jpg' -> '2465.jpg' (num_crop_image)
# '1415.jpg' -> '2466.jpg' (num_crop_image)
# '1416.jpg' -> '2467.jpg' (num_crop_image)
# '1417.jpg' -> '2468.jpg' (num_crop_image)
# '1418.jpg' -> '2469.jpg' (num_crop_image)
# '1419.jpg' -> '2470.jpg' (num_crop_image)
# '1420.jpg' -> '2471.jpg' (num_crop_image)
# '1421.jpg' -> '2472.jpg' (num_crop_image)
# '1422.jpg' -> '2473.jpg' (num_crop_image)
# '1423.jpg' -> '2474.jpg' (num_crop_image)
# '1424.jpg' -> '2475.jpg' (num_crop_image)
# '1425.jpg' -> '2476.jpg' (num_crop_image)
# '1426.jpg' -> '2477.jpg' (num_crop_image)
# '1427.jpg' -> '2478.jpg' (num_crop_image)
# '1428.jpg' -> '2479.jpg' (num_crop_image)
# '1429.jpg' -> '2480.jpg' (num_crop_image)
# '1430.jpg' -> '2481.jpg' (num_crop_image)
# '1431.jpg' -> '2482.jpg' (num_crop_image)
# '1432.jpg' -> '2483.jpg' (num_crop_image)
# '1433.jpg' -> '2484.jpg' (num_crop_image)
# '1434.jpg' -> '2485.jpg' (num_crop_image)
# '1435.jpg' -> '2486.jpg' (num_crop_image)
# '1436.jpg' -> '2487.jpg' (num_crop_image)
# '1437.jpg' -> '2488.jpg' (num_crop_image)
# '1438.jpg' -> '2489.jpg' (num_crop_image)
# '1439.jpg' -> '2490.jpg' (num_crop_image)
# '1440.jpg' -> '2491.jpg' (num_crop_image)
# '1441.jpg' -> '2492.jpg' (num_crop_image)
# '1442.jpg' -> '2493.jpg' (num_crop_image)
# '1443.jpg' -> '2494.jpg' (num_crop_image)
# '1444.jpg' -> '2495.jpg' (num_crop_image)
# '1445.jpg' -> '2496.jpg' (num_crop_image)
# '1446.jpg' -> '2497.jpg' (num_crop_image)
# '1447.jpg' -> '2498.jpg' (num_crop_image)
# '1448.jpg' -> '2499.jpg' (num_crop_image)
# '1449.jpg' -> '2500.jpg' (num_crop_image)
# '1450.jpg' -> '2501.jpg' (num_crop_image)
# '1451.jpg' -> '2502.jpg' (num_crop_image)
# '1452.jpg' -> '2503.jpg' (num_crop_image)
# '1453.jpg' -> '2504.jpg' (num_crop_image)
# '1454.jpg' -> '2505.jpg' (num_crop_image)
# '1455.jpg' -> '2506.jpg' (num_crop_image)
# '1456.jpg' -> '2507.jpg' (num_crop_image)
# '1457.jpg' -> '2508.jpg' (num_crop_image)
# '1458.jpg' -> '2509.jpg' (num_crop_image)
# '1459.jpg' -> '2510.jpg' (num_crop_image)
# '1460.jpg' -> '2511.jpg' (num_crop_image)
# '1461.jpg' -> '2512.jpg' (num_crop_image)
# '1462.jpg' -> '2513.jpg' (num_crop_image)
# '1463.jpg' -> '2514.jpg' (num_crop_image)
# '1464.jpg' -> '2515.jpg' (num_crop_image)
# '1465.jpg' -> '2516.jpg' (num_crop_image)
# '1466.jpg' -> '2517.jpg' (num_crop_image)
# '1467.jpg' -> '2518.jpg' (num_crop_image)
# '1468.jpg' -> '2519.jpg' (num_crop_image)
# '1469.jpg' -> '2520.jpg' (num_crop_image)
# '1470.jpg' -> '2521.jpg' (num_crop_image)
# '1471.jpg' -> '2522.jpg' (num_crop_image)
# '1472.jpg' -> '2523.jpg' (num_crop_image)
# '1473.jpg' -> '2524.jpg' (num_crop_image)
# '1474.jpg' -> '2525.jpg' (num_crop_image)
# '1475.jpg' -> '2526.jpg' (num_crop_image)
# '1476.jpg' -> '2527.jpg' (num_crop_image)
# '1477.jpg' -> '2528.jpg' (num_crop_image)
# '1478.jpg' -> '2529.jpg' (num_crop_image)
# '1479.jpg' -> '2530.jpg' (num_crop_image)
# '1480.jpg' -> '2531.jpg' (num_crop_image)
# '1481.jpg' -> '2532.jpg' (num_crop_image)
# '1482.jpg' -> '2533.jpg' (num_crop_image)
# '1483.jpg' -> '2534.jpg' (num_crop_image)
# '1484.jpg' -> '2535.jpg' (num_crop_image)
# '1485.jpg' -> '2536.jpg' (num_crop_image)
# '1486.jpg' -> '2537.jpg' (num_crop_image)
# '1487.jpg' -> '2538.jpg' (num_crop_image)
# '1488.jpg' -> '2539.jpg' (num_crop_image)
# '1489.jpg' -> '2540.jpg' (num_crop_image)
# '1490.jpg' -> '2541.jpg' (num_crop_image)
# '1491.jpg' -> '2542.jpg' (num_crop_image)
# '1492.jpg' -> '2543.jpg' (num_crop_image)
# '1493.jpg' -> '2544.jpg' (num_crop_image)
# '1494.jpg' -> '2545.jpg' (num_crop_image)
# '1495.jpg' -> '2546.jpg' (num_crop_image)
# '1496.jpg' -> '2547.jpg' (num_crop_image)
# '1497.jpg' -> '2548.jpg' (num_crop_image)
# '1498.jpg' -> '2549.jpg' (num_crop_image)
# '1499.jpg' -> '2550.jpg' (num_crop_image)
# '1500.jpg' -> '2551.jpg' (num_crop_image)
# '1501.jpg' -> '2552.jpg' (num_crop_image)
# '1502.jpg' -> '2553.jpg' (num_crop_image)
# '1503.jpg' -> '2554.jpg' (num_crop_image)
# '1504.jpg' -> '2555.jpg' (num_crop_image)
# '1505.jpg' -> '2556.jpg' (num_crop_image)
# '1506.jpg' -> '2557.jpg' (num_crop_image)
# '1507.jpg' -> '2558.jpg' (num_crop_image)
# '1508.jpg' -> '2559.jpg' (num_crop_image)
# '1509.jpg' -> '2560.jpg' (num_crop_image)
# '1510.jpg' -> '2561.jpg' (num_crop_image)
# '1511.jpg' -> '2562.jpg' (num_crop_image)
# '1512.jpg' -> '2563.jpg' (num_crop_image)
# '1513.jpg' -> '2564.jpg' (num_crop_image)
# '1514.jpg' -> '2565.jpg' (num_crop_image)
# '1515.jpg' -> '2566.jpg' (num_crop_image)
# '1516.jpg' -> '2567.jpg' (num_crop_image)
# '1517.jpg' -> '2568.jpg' (num_crop_image)
# '1518.jpg' -> '2569.jpg' (num_crop_image)
# '1519.jpg' -> '2570.jpg' (num_crop_image)
# '1520.jpg' -> '2571.jpg' (num_crop_image)
# '1521.jpg' -> '2572.jpg' (num_crop_image)
# '1522.jpg' -> '2573.jpg' (num_crop_image)
# '1523.jpg' -> '2574.jpg' (num_crop_image)
# '1524.jpg' -> '2575.jpg' (num_crop_image)
# '1525.jpg' -> '2576.jpg' (num_crop_image)
# '1526.jpg' -> '2577.jpg' (num_crop_image)
# '1527.jpg' -> '2578.jpg' (num_crop_image)
# '1528.jpg' -> '2579.jpg' (num_crop_image)
# '1529.jpg' -> '2580.jpg' (num_crop_image)
# '1530.jpg' -> '2581.jpg' (num_crop_image)
# '1531.jpg' -> '2582.jpg' (num_crop_image)
# '1532.jpg' -> '2583.jpg' (num_crop_image)
# '1533.jpg' -> '2584.jpg' (num_crop_image)
# '1534.jpg' -> '2585.jpg' (num_crop_image)
# '1535.jpg' -> '2586.jpg' (num_crop_image)
# '1536.jpg' -> '2587.jpg' (num_crop_image)
# '1537.jpg' -> '2588.jpg' (num_crop_image)
# '1538.jpg' -> '2589.jpg' (num_crop_image)
# '1539.jpg' -> '2590.jpg' (num_crop_image)
# '1540.jpg' -> '2591.jpg' (num_crop_image)
# '1541.jpg' -> '2592.jpg' (num_crop_image)
# '1542.jpg' -> '2593.jpg' (num_crop_image)
# '1543.jpg' -> '2594.jpg' (num_crop_image)
# '1544.jpg' -> '2595.jpg' (num_crop_image)
# '1545.jpg' -> '2596.jpg' (num_crop_image)
# '1546.jpg' -> '2597.jpg' (num_crop_image)
# '1547.jpg' -> '2598.jpg' (num_crop_image)
# '1548.jpg' -> '2599.jpg' (num_crop_image)
# '1549.jpg' -> '2600.jpg' (num_crop_image)
# '1550.jpg' -> '2601.jpg' (num_crop_image)
# '1551.jpg' -> '2602.jpg' (num_crop_image)
# '1552.jpg' -> '2603.jpg' (num_crop_image)
# '1553.jpg' -> '2604.jpg' (num_crop_image)
# '1554.jpg' -> '2605.jpg' (num_crop_image)
# '1555.jpg' -> '2606.jpg' (num_crop_image)
# '1556.jpg' -> '2607.jpg' (num_crop_image)
# '1557.jpg' -> '2608.jpg' (num_crop_image)
# '1558.jpg' -> '2609.jpg' (num_crop_image)
# '1559.jpg' -> '2610.jpg' (num_crop_image)
# '1560.jpg' -> '2611.jpg' (num_crop_image)
# '1561.jpg' -> '2612.jpg' (num_crop_image)
# '1562.jpg' -> '2613.jpg' (num_crop_image)
# '1563.jpg' -> '2614.jpg' (num_crop_image)
# '1564.jpg' -> '2615.jpg' (num_crop_image)
# '1565.jpg' -> '2616.jpg' (num_crop_image)
# '1566.jpg' -> '2617.jpg' (num_crop_image)
# '1567.jpg' -> '2618.jpg' (num_crop_image)
# '1568.jpg' -> '2619.jpg' (num_crop_image)
# '1569.jpg' -> '2620.jpg' (num_crop_image)
# '1570.jpg' -> '2621.jpg' (num_crop_image)
# '1571.jpg' -> '2622.jpg' (num_crop_image)
# '1572.jpg' -> '2623.jpg' (num_crop_image)
# '1573.jpg' -> '2624.jpg' (num_crop_image)
# '1574.jpg' -> '2625.jpg' (num_crop_image)
# '1575.jpg' -> '2626.jpg' (num_crop_image)
# '1576.jpg' -> '2627.jpg' (num_crop_image)
# '1577.jpg' -> '2628.jpg' (num_crop_image)
# '1578.jpg' -> '2629.jpg' (num_crop_image)
# '1579.jpg' -> '2630.jpg' (num_crop_image)
# '1580.jpg' -> '2631.jpg' (num_crop_image)
# '1581.jpg' -> '2632.jpg' (num_crop_image)
# '1582.jpg' -> '2633.jpg' (num_crop_image)
# '1583.jpg' -> '2634.jpg' (num_crop_image)
# '1584.jpg' -> '2635.jpg' (num_crop_image)
# '1585.jpg' -> '2636.jpg' (num_crop_image)
# '1586.jpg' -> '2637.jpg' (num_crop_image)
# '1587.jpg' -> '2638.jpg' (num_crop_image)
# '1588.jpg' -> '2639.jpg' (num_crop_image)
# '1589.jpg' -> '2640.jpg' (num_crop_image)
# '1590.jpg' -> '2641.jpg' (num_crop_image)
# '1591.jpg' -> '2642.jpg' (num_crop_image)
# '1592.jpg' -> '2643.jpg' (num_crop_image)
# '1593.jpg' -> '2644.jpg' (num_crop_image)
# '1594.jpg' -> '2645.jpg' (num_crop_image)
# '1595.jpg' -> '2646.jpg' (num_crop_image)
# '1596.jpg' -> '2647.jpg' (num_crop_image)
# '1597.jpg' -> '2648.jpg' (num_crop_image)
# '1598.jpg' -> '2649.jpg' (num_crop_image)
# '1599.jpg' -> '2650.jpg' (num_crop_image)
# '1600.jpg' -> '2651.jpg' (num_crop_image)
# '1601.jpg' -> '2652.jpg' (num_crop_image)
# '1602.jpg' -> '2653.jpg' (num_crop_image)
# '1603.jpg' -> '2654.jpg' (num_crop_image)
# '1604.jpg' -> '2655.jpg' (num_crop_image)
# '1605.jpg' -> '2656.jpg' (num_crop_image)
# '1606.jpg' -> '2657.jpg' (num_crop_image)
# '1607.jpg' -> '2658.jpg' (num_crop_image)
# '1608.jpg' -> '2659.jpg' (num_crop_image)
# '1609.jpg' -> '2660.jpg' (num_crop_image)
# '1610.jpg' -> '2661.jpg' (num_crop_image)
# '1611.jpg' -> '2662.jpg' (num_crop_image)
# '1612.jpg' -> '2663.jpg' (num_crop_image)
# '1613.jpg' -> '2664.jpg' (num_crop_image)
# '1614.jpg' -> '2665.jpg' (num_crop_image)
# '1615.jpg' -> '2666.jpg' (num_crop_image)
# '1616.jpg' -> '2667.jpg' (num_crop_image)
# '1617.jpg' -> '2668.jpg' (num_crop_image)
# '1618.jpg' -> '2669.jpg' (num_crop_image)
# '1619.jpg' -> '2670.jpg' (num_crop_image)
# '1620.jpg' -> '2671.jpg' (num_crop_image)
# '1621.jpg' -> '2672.jpg' (num_crop_image)
# '1622.jpg' -> '2673.jpg' (num_crop_image)
# '1623.jpg' -> '2674.jpg' (num_crop_image)
# '1624.jpg' -> '2675.jpg' (num_crop_image)
# '1625.jpg' -> '2676.jpg' (num_crop_image)
# '1626.jpg' -> '2677.jpg' (num_crop_image)
# '1627.jpg' -> '2678.jpg' (num_crop_image)
# '1628.jpg' -> '2679.jpg' (num_crop_image)
# '1629.jpg' -> '2680.jpg' (num_crop_image)
# '1630.jpg' -> '2681.jpg' (num_crop_image)
# '1631.jpg' -> '2682.jpg' (num_crop_image)
# '1632.jpg' -> '2683.jpg' (num_crop_image)
# '1633.jpg' -> '2684.jpg' (num_crop_image)
# '1634.jpg' -> '2685.jpg' (num_crop_image)
# '1635.jpg' -> '2686.jpg' (num_crop_image)
# '1636.jpg' -> '2687.jpg' (num_crop_image)
# '1637.jpg' -> '2688.jpg' (num_crop_image)
# '1638.jpg' -> '2689.jpg' (num_crop_image)
# '1639.jpg' -> '2690.jpg' (num_crop_image)
# '1640.jpg' -> '2691.jpg' (num_crop_image)
# '1641.jpg' -> '2692.jpg' (num_crop_image)
# '1642.jpg' -> '2693.jpg' (num_crop_image)
# '1643.jpg' -> '2694.jpg' (num_crop_image)
# '1644.jpg' -> '2695.jpg' (num_crop_image)
# '1645.jpg' -> '2696.jpg' (num_crop_image)
# '1646.jpg' -> '2697.jpg' (num_crop_image)
# '1647.jpg' -> '2698.jpg' (num_crop_image)
# '1648.jpg' -> '2699.jpg' (num_crop_image)
# '1649.jpg' -> '2700.jpg' (num_crop_image)
# '1650.jpg' -> '2701.jpg' (num_crop_image)
# '1651.jpg' -> '2702.jpg' (num_crop_image)
# '1652.jpg' -> '2703.jpg' (num_crop_image)
# '1653.jpg' -> '2704.jpg' (num_crop_image)
# '1654.jpg' -> '2705.jpg' (num_crop_image)
# '1655.jpg' -> '2706.jpg' (num_crop_image)
# '1656.jpg' -> '2707.jpg' (num_crop_image)
# '1657.jpg' -> '2708.jpg' (num_crop_image)
# '1658.jpg' -> '2709.jpg' (num_crop_image)
# '1659.jpg' -> '2710.jpg' (num_crop_image)
# '1660.jpg' -> '2711.jpg' (num_crop_image)
# '1661.jpg' -> '2712.jpg' (num_crop_image)
# '1662.jpg' -> '2713.jpg' (num_crop_image)
# '1663.jpg' -> '2714.jpg' (num_crop_image)
# '1664.jpg' -> '2715.jpg' (num_crop_image)
# '1665.jpg' -> '2716.jpg' (num_crop_image)
# '1666.jpg' -> '2717.jpg' (num_crop_image)
# '1667.jpg' -> '2718.jpg' (num_crop_image)
# '1668.jpg' -> '2719.jpg' (num_crop_image)
# '1669.jpg' -> '2720.jpg' (num_crop_image)
# '1670.jpg' -> '2721.jpg' (num_crop_image)
# '1671.jpg' -> '2722.jpg' (num_crop_image)
# '1672.jpg' -> '2723.jpg' (num_crop_image)
# '1673.jpg' -> '2724.jpg' (num_crop_image)
# '1674.jpg' -> '2725.jpg' (num_crop_image)
# '1675.jpg' -> '2726.jpg' (num_crop_image)
# '1676.jpg' -> '2727.jpg' (num_crop_image)
# '1677.jpg' -> '2728.jpg' (num_crop_image)
# '1678.jpg' -> '2729.jpg' (num_crop_image)
# '1679.jpg' -> '2730.jpg' (num_crop_image)
# '1680.jpg' -> '2731.jpg' (num_crop_image)
# '1681.jpg' -> '2732.jpg' (num_crop_image)
# '1682.jpg' -> '2733.jpg' (num_crop_image)
# '1683.jpg' -> '2734.jpg' (num_crop_image)
# '1684.jpg' -> '2735.jpg' (num_crop_image)
# '1685.jpg' -> '2736.jpg' (num_crop_image)
# '1686.jpg' -> '2737.jpg' (num_crop_image)
# '1687.jpg' -> '2738.jpg' (num_crop_image)
# '1688.jpg' -> '2739.jpg' (num_crop_image)
# '1689.jpg' -> '2740.jpg' (num_crop_image)
# '1690.jpg' -> '2741.jpg' (num_crop_image)
# '1691.jpg' -> '2742.jpg' (num_crop_image)
# '1692.jpg' -> '2743.jpg' (num_crop_image)
# '1693.jpg' -> '2744.jpg' (num_crop_image)
# '1694.jpg' -> '2745.jpg' (num_crop_image)
# '1695.jpg' -> '2746.jpg' (num_crop_image)
# '1696.jpg' -> '2747.jpg' (num_crop_image)
# '1697.jpg' -> '2748.jpg' (num_crop_image)
# '1698.jpg' -> '2749.jpg' (num_crop_image)
# '1699.jpg' -> '2750.jpg' (num_crop_image)
# '1700.jpg' -> '2751.jpg' (num_crop_image)
# '1701.jpg' -> '2752.jpg' (num_crop_image)
# '1702.jpg' -> '2753.jpg' (num_crop_image)
# '1703.jpg' -> '2754.jpg' (num_crop_image)
# '1704.jpg' -> '2755.jpg' (num_crop_image)
# '1705.jpg' -> '2756.jpg' (num_crop_image)
# '1706.jpg' -> '2757.jpg' (num_crop_image)
# '1707.jpg' -> '2758.jpg' (num_crop_image)
# '1708.jpg' -> '2759.jpg' (num_crop_image)
# '1709.jpg' -> '2760.jpg' (num_crop_image)
# '1710.jpg' -> '2761.jpg' (num_crop_image)
# '1711.jpg' -> '2762.jpg' (num_crop_image)
# '1712.jpg' -> '2763.jpg' (num_crop_image)
# '1713.jpg' -> '2764.jpg' (num_crop_image)
# '1714.jpg' -> '2765.jpg' (num_crop_image)
# '1715.jpg' -> '2766.jpg' (num_crop_image)
# '1716.jpg' -> '2767.jpg' (num_crop_image)
# '1717.jpg' -> '2768.jpg' (num_crop_image)
# '1718.jpg' -> '2769.jpg' (num_crop_image)
# '1719.jpg' -> '2770.jpg' (num_crop_image)
# '1720.jpg' -> '2771.jpg' (num_crop_image)
# '1721.jpg' -> '2772.jpg' (num_crop_image)
# '1722.jpg' -> '2773.jpg' (num_crop_image)
# '1723.jpg' -> '2774.jpg' (num_crop_image)
# '1724.jpg' -> '2775.jpg' (num_crop_image)
# '1725.jpg' -> '2776.jpg' (num_crop_image)
# '1726.jpg' -> '2777.jpg' (num_crop_image)
# '1727.jpg' -> '2778.jpg' (num_crop_image)
# '1728.jpg' -> '2779.jpg' (num_crop_image)
# '1729.jpg' -> '2780.jpg' (num_crop_image)
# '1730.jpg' -> '2781.jpg' (num_crop_image)
# '1731.jpg' -> '2782.jpg' (num_crop_image)
# '1732.jpg' -> '2783.jpg' (num_crop_image)
# '1733.jpg' -> '2784.jpg' (num_crop_image)
# '1734.jpg' -> '2785.jpg' (num_crop_image)
# '1735.jpg' -> '2786.jpg' (num_crop_image)
# '1736.jpg' -> '2787.jpg' (num_crop_image)
# '1737.jpg' -> '2788.jpg' (num_crop_image)
# '1738.jpg' -> '2789.jpg' (num_crop_image)
# '1739.jpg' -> '2790.jpg' (num_crop_image)
# '1740.jpg' -> '2791.jpg' (num_crop_image)
# '1741.jpg' -> '2792.jpg' (num_crop_image)
# '1742.jpg' -> '2793.jpg' (num_crop_image)
# '1743.jpg' -> '2794.jpg' (num_crop_image)
# '1744.jpg' -> '2795.jpg' (num_crop_image)
# '1745.jpg' -> '2796.jpg' (num_crop_image)
# '1746.jpg' -> '2797.jpg' (num_crop_image)
# '1747.jpg' -> '2798.jpg' (num_crop_image)
# '1748.jpg' -> '2799.jpg' (num_crop_image)
# '1749.jpg' -> '2800.jpg' (num_crop_image)
# '1750.jpg' -> '2801.jpg' (num_crop_image)
# '1751.jpg' -> '2802.jpg' (num_crop_image)
# '1752.jpg' -> '2803.jpg' (num_crop_image)
# '1753.jpg' -> '2804.jpg' (num_crop_image)
# '1754.jpg' -> '2805.jpg' (num_crop_image)
# '1755.jpg' -> '2806.jpg' (num_crop_image)
# '1756.jpg' -> '2807.jpg' (num_crop_image)
# '1757.jpg' -> '2808.jpg' (num_crop_image)
# '1758.jpg' -> '2809.jpg' (num_crop_image)
# '1759.jpg' -> '2810.jpg' (num_crop_image)
# '1760.jpg' -> '2811.jpg' (num_crop_image)
# '1761.jpg' -> '2812.jpg' (num_crop_image)
# '1762.jpg' -> '2813.jpg' (num_crop_image)
# '1763.jpg' -> '2814.jpg' (num_crop_image)
# '1764.jpg' -> '2815.jpg' (num_crop_image)
# '1765.jpg' -> '2816.jpg' (num_crop_image)
# '1766.jpg' -> '2817.jpg' (num_crop_image)
# '1767.jpg' -> '2818.jpg' (num_crop_image)
# '1768.jpg' -> '2819.jpg' (num_crop_image)
# '1769.jpg' -> '2820.jpg' (num_crop_image)
# '1770.jpg' -> '2821.jpg' (num_crop_image)
# '1771.jpg' -> '2822.jpg' (num_crop_image)
# '1772.jpg' -> '2823.jpg' (num_crop_image)
# '1773.jpg' -> '2824.jpg' (num_crop_image)
# '1774.jpg' -> '2825.jpg' (num_crop_image)
# '1775.jpg' -> '2826.jpg' (num_crop_image)
# '1776.jpg' -> '2827.jpg' (num_crop_image)
# '1777.jpg' -> '2828.jpg' (num_crop_image)
# '1778.jpg' -> '2829.jpg' (num_crop_image)
# '1779.jpg' -> '2830.jpg' (num_crop_image)
# '1780.jpg' -> '2831.jpg' (num_crop_image)
# '1781.jpg' -> '2832.jpg' (num_crop_image)
# '1782.jpg' -> '2833.jpg' (num_crop_image)
# '1783.jpg' -> '2834.jpg' (num_crop_image)
# '1784.jpg' -> '2835.jpg' (num_crop_image)
# '1785.jpg' -> '2836.jpg' (num_crop_image)
# '1786.jpg' -> '2837.jpg' (num_crop_image)
# '1787.jpg' -> '2838.jpg' (num_crop_image)
# '1788.jpg' -> '2839.jpg' (num_crop_image)
# '1789.jpg' -> '2840.jpg' (num_crop_image)
# '1790.jpg' -> '2841.jpg' (num_crop_image)
# '1791.jpg' -> '2842.jpg' (num_crop_image)
# '1792.jpg' -> '2843.jpg' (num_crop_image)
# '1793.jpg' -> '2844.jpg' (num_crop_image)
# '1794.jpg' -> '2845.jpg' (num_crop_image)
# '1795.jpg' -> '2846.jpg' (num_crop_image)
# '1796.jpg' -> '2847.jpg' (num_crop_image)
# '1797.jpg' -> '2848.jpg' (num_crop_image)
# '1798.jpg' -> '2849.jpg' (num_crop_image)
# '1799.jpg' -> '2850.jpg' (num_crop_image)
# '1800.jpg' -> '2851.jpg' (num_crop_image)
# '1801.jpg' -> '2852.jpg' (num_crop_image)
# '1802.jpg' -> '2853.jpg' (num_crop_image)
# '1803.jpg' -> '2854.jpg' (num_crop_image)
# '1804.jpg' -> '2855.jpg' (num_crop_image)
# '1805.jpg' -> '2856.jpg' (num_crop_image)
# '1806.jpg' -> '2857.jpg' (num_crop_image)
# '1807.jpg' -> '2858.jpg' (num_crop_image)
# '1808.jpg' -> '2859.jpg' (num_crop_image)
# '1809.jpg' -> '2860.jpg' (num_crop_image)
# '1810.jpg' -> '2861.jpg' (num_crop_image)
# '1811.jpg' -> '2862.jpg' (num_crop_image)
# '1812.jpg' -> '2863.jpg' (num_crop_image)
# '1813.jpg' -> '2864.jpg' (num_crop_image)
# '1814.jpg' -> '2865.jpg' (num_crop_image)
# '1815.jpg' -> '2866.jpg' (num_crop_image)
# '1816.jpg' -> '2867.jpg' (num_crop_image)
# '1817.jpg' -> '2868.jpg' (num_crop_image)
# '1818.jpg' -> '2869.jpg' (num_crop_image)
# '1819.jpg' -> '2870.jpg' (num_crop_image)
# '1820.jpg' -> '2871.jpg' (num_crop_image)
# '1821.jpg' -> '2872.jpg' (num_crop_image)
# '1822.jpg' -> '2873.jpg' (num_crop_image)
# '1823.jpg' -> '2874.jpg' (num_crop_image)
# '1824.jpg' -> '2875.jpg' (num_crop_image)
# '1825.jpg' -> '2876.jpg' (num_crop_image)
# '1826.jpg' -> '2877.jpg' (num_crop_image)
# '1827.jpg' -> '2878.jpg' (num_crop_image)
# '1828.jpg' -> '2879.jpg' (num_crop_image)
# '1829.jpg' -> '2880.jpg' (num_crop_image)
# '1830.jpg' -> '2881.jpg' (num_crop_image)
# '1831.jpg' -> '2882.jpg' (num_crop_image)
# '1832.jpg' -> '2883.jpg' (num_crop_image)
# '1833.jpg' -> '2884.jpg' (num_crop_image)
# '1834.jpg' -> '2885.jpg' (num_crop_image)
# '1835.jpg' -> '2886.jpg' (num_crop_image)
# '1836.jpg' -> '2887.jpg' (num_crop_image)
# '1837.jpg' -> '2888.jpg' (num_crop_image)
# '1838.jpg' -> '2889.jpg' (num_crop_image)
# '1839.jpg' -> '2890.jpg' (num_crop_image)
# '1840.jpg' -> '2891.jpg' (num_crop_image)
# '1841.jpg' -> '2892.jpg' (num_crop_image)
# '1842.jpg' -> '2893.jpg' (num_crop_image)
# '1843.jpg' -> '2894.jpg' (num_crop_image)
# '1844.jpg' -> '2895.jpg' (num_crop_image)
# '1845.jpg' -> '2896.jpg' (num_crop_image)
# '1846.jpg' -> '2897.jpg' (num_crop_image)
# '1847.jpg' -> '2898.jpg' (num_crop_image)
# '1848.jpg' -> '2899.jpg' (num_crop_image)
# '1849.jpg' -> '2900.jpg' (num_crop_image)
# '1850.jpg' -> '2901.jpg' (num_crop_image)
# '1851.jpg' -> '2902.jpg' (num_crop_image)
# '1852.jpg' -> '2903.jpg' (num_crop_image)
# '1853.jpg' -> '2904.jpg' (num_crop_image)
# '1854.jpg' -> '2905.jpg' (num_crop_image)
# '1855.jpg' -> '2906.jpg' (num_crop_image)
# '1856.jpg' -> '2907.jpg' (num_crop_image)
# '1857.jpg' -> '2908.jpg' (num_crop_image)
# '1858.jpg' -> '2909.jpg' (num_crop_image)
# '1859.jpg' -> '2910.jpg' (num_crop_image)
# '1860.jpg' -> '2911.jpg' (num_crop_image)
# '1861.jpg' -> '2912.jpg' (num_crop_image)
# '1862.jpg' -> '2913.jpg' (num_crop_image)
# '1863.jpg' -> '2914.jpg' (num_crop_image)
# '1864.jpg' -> '2915.jpg' (num_crop_image)
# '1865.jpg' -> '2916.jpg' (num_crop_image)
# '1866.jpg' -> '2917.jpg' (num_crop_image)
# '1867.jpg' -> '2918.jpg' (num_crop_image)
# '1868.jpg' -> '2919.jpg' (num_crop_image)
# '1869.jpg' -> '2920.jpg' (num_crop_image)
# '1870.jpg' -> '2921.jpg' (num_crop_image)
# '1871.jpg' -> '2922.jpg' (num_crop_image)
# '1872.jpg' -> '2923.jpg' (num_crop_image)
# '1873.jpg' -> '2924.jpg' (num_crop_image)
# '1874.jpg' -> '2925.jpg' (num_crop_image)
# '1875.jpg' -> '2926.jpg' (num_crop_image)
# '1876.jpg' -> '2927.jpg' (num_crop_image)
# '1877.jpg' -> '2928.jpg' (num_crop_image)
# '1878.jpg' -> '2929.jpg' (num_crop_image)
# '1879.jpg' -> '2930.jpg' (num_crop_image)
# '1880.jpg' -> '2931.jpg' (num_crop_image)
# '1881.jpg' -> '2932.jpg' (num_crop_image)
# '1882.jpg' -> '2933.jpg' (num_crop_image)
# '1883.jpg' -> '2934.jpg' (num_crop_image)
# '1884.jpg' -> '2935.jpg' (num_crop_image)
# '1885.jpg' -> '2936.jpg' (num_crop_image)
# '1886.jpg' -> '2937.jpg' (num_crop_image)
# '1887.jpg' -> '2938.jpg' (num_crop_image)
# '1888.jpg' -> '2939.jpg' (num_crop_image)
# '1889.jpg' -> '2940.jpg' (num_crop_image)
# '1890.jpg' -> '2941.jpg' (num_crop_image)
# '1891.jpg' -> '2942.jpg' (num_crop_image)
# '1892.jpg' -> '2943.jpg' (num_crop_image)
# '1893.jpg' -> '2944.jpg' (num_crop_image)
# '1894.jpg' -> '2945.jpg' (num_crop_image)
# '1895.jpg' -> '2946.jpg' (num_crop_image)
# '1896.jpg' -> '2947.jpg' (num_crop_image)
# '1897.jpg' -> '2948.jpg' (num_crop_image)
# '1898.jpg' -> '2949.jpg' (num_crop_image)
# '1899.jpg' -> '2950.jpg' (num_crop_image)
# '1900.jpg' -> '2951.jpg' (num_crop_image)
# '1901.jpg' -> '2952.jpg' (num_crop_image)
# '1902.jpg' -> '2953.jpg' (num_crop_image)
# '1903.jpg' -> '2954.jpg' (num_crop_image)
# '1904.jpg' -> '2955.jpg' (num_crop_image)
# '1905.jpg' -> '2956.jpg' (num_crop_image)
# '1906.jpg' -> '2957.jpg' (num_crop_image)
# '1907.jpg' -> '2958.jpg' (num_crop_image)
# '1908.jpg' -> '2959.jpg' (num_crop_image)
# '1909.jpg' -> '2960.jpg' (num_crop_image)
# '1910.jpg' -> '2961.jpg' (num_crop_image)
# '1911.jpg' -> '2962.jpg' (num_crop_image)
# '1912.jpg' -> '2963.jpg' (num_crop_image)
# '1913.jpg' -> '2964.jpg' (num_crop_image)
# '1914.jpg' -> '2965.jpg' (num_crop_image)
# '1915.jpg' -> '2966.jpg' (num_crop_image)
# '1916.jpg' -> '2967.jpg' (num_crop_image)
# '1917.jpg' -> '2968.jpg' (num_crop_image)
# '1918.jpg' -> '2969.jpg' (num_crop_image)
# '1919.jpg' -> '2970.jpg' (num_crop_image)
# '1920.jpg' -> '2971.jpg' (num_crop_image)
# '1921.jpg' -> '2972.jpg' (num_crop_image)
# '1922.jpg' -> '2973.jpg' (num_crop_image)
# '1923.jpg' -> '2974.jpg' (num_crop_image)
# '1924.jpg' -> '2975.jpg' (num_crop_image)
# '1925.jpg' -> '2976.jpg' (num_crop_image)
# '1926.jpg' -> '2977.jpg' (num_crop_image)
# '1927.jpg' -> '2978.jpg' (num_crop_image)
# '1928.jpg' -> '2979.jpg' (num_crop_image)
# '1929.jpg' -> '2980.jpg' (num_crop_image)
# '193.jpg' -> '2981.jpg' (num_crop_image)
# '1930.jpg' -> '2982.jpg' (num_crop_image)
# '1931.jpg' -> '2983.jpg' (num_crop_image)
# '1932.jpg' -> '2984.jpg' (num_crop_image)
# '1933.jpg' -> '2985.jpg' (num_crop_image)
# '1934.jpg' -> '2986.jpg' (num_crop_image)
# '1935.jpg' -> '2987.jpg' (num_crop_image)
# '1936.jpg' -> '2988.jpg' (num_crop_image)
# '1937.jpg' -> '2989.jpg' (num_crop_image)
# '1938.jpg' -> '2990.jpg' (num_crop_image)
# '1939.jpg' -> '2991.jpg' (num_crop_image)
# '194.jpg' -> '2992.jpg' (num_crop_image)
# '1940.jpg' -> '2993.jpg' (num_crop_image)
# '1941.jpg' -> '2994.jpg' (num_crop_image)
# '1942.jpg' -> '2995.jpg' (num_crop_image)
# '1943.jpg' -> '2996.jpg' (num_crop_image)
# '1944.jpg' -> '2997.jpg' (num_crop_image)
# '1945.jpg' -> '2998.jpg' (num_crop_image)
# '1946.jpg' -> '2999.jpg' (num_crop_image)
# '1947.jpg' -> '3000.jpg' (num_crop_image)
# '1948.jpg' -> '3001.jpg' (num_crop_image)
# '1949.jpg' -> '3002.jpg' (num_crop_image)
# '195.jpg' -> '3003.jpg' (num_crop_image)
# '1950.jpg' -> '3004.jpg' (num_crop_image)
# '1951.jpg' -> '3005.jpg' (num_crop_image)
# '1952.jpg' -> '3006.jpg' (num_crop_image)
# '1953.jpg' -> '3007.jpg' (num_crop_image)
# '1954.jpg' -> '3008.jpg' (num_crop_image)
# '1955.jpg' -> '3009.jpg' (num_crop_image)
# '1956.jpg' -> '3010.jpg' (num_crop_image)
# '1957.jpg' -> '3011.jpg' (num_crop_image)
# '1958.jpg' -> '3012.jpg' (num_crop_image)
# '1959.jpg' -> '3013.jpg' (num_crop_image)
# '196.jpg' -> '3014.jpg' (num_crop_image)
# '1960.jpg' -> '3015.jpg' (num_crop_image)
# '1961.jpg' -> '3016.jpg' (num_crop_image)
# '1962.jpg' -> '3017.jpg' (num_crop_image)
# '1963.jpg' -> '3018.jpg' (num_crop_image)
# '1964.jpg' -> '3019.jpg' (num_crop_image)
# '1965.jpg' -> '3020.jpg' (num_crop_image)
# '1966.jpg' -> '3021.jpg' (num_crop_image)
# '1967.jpg' -> '3022.jpg' (num_crop_image)
# '1968.jpg' -> '3023.jpg' (num_crop_image)
# '1969.jpg' -> '3024.jpg' (num_crop_image)
# '197.jpg' -> '3025.jpg' (num_crop_image)
# '1970.jpg' -> '3026.jpg' (num_crop_image)
# '1971.jpg' -> '3027.jpg' (num_crop_image)
# '1972.jpg' -> '3028.jpg' (num_crop_image)
# '1973.jpg' -> '3029.jpg' (num_crop_image)
# '1974.jpg' -> '3030.jpg' (num_crop_image)
# '1975.jpg' -> '3031.jpg' (num_crop_image)
# '1976.jpg' -> '3032.jpg' (num_crop_image)
# '1977.jpg' -> '3033.jpg' (num_crop_image)
# '1978.jpg' -> '3034.jpg' (num_crop_image)
# '1979.jpg' -> '3035.jpg' (num_crop_image)
# '198.jpg' -> '3036.jpg' (num_crop_image)
# '1980.jpg' -> '3037.jpg' (num_crop_image)
# '1981.jpg' -> '3038.jpg' (num_crop_image)
# '1982.jpg' -> '3039.jpg' (num_crop_image)
# '1983.jpg' -> '3040.jpg' (num_crop_image)
# '1984.jpg' -> '3041.jpg' (num_crop_image)
# '1985.jpg' -> '3042.jpg' (num_crop_image)
# '1986.jpg' -> '3043.jpg' (num_crop_image)
# '1987.jpg' -> '3044.jpg' (num_crop_image)
# '1988.jpg' -> '3045.jpg' (num_crop_image)
# '1989.jpg' -> '3046.jpg' (num_crop_image)
# '199.jpg' -> '3047.jpg' (num_crop_image)
# '1990.jpg' -> '3048.jpg' (num_crop_image)
# '1991.jpg' -> '3049.jpg' (num_crop_image)
# '1992.jpg' -> '3050.jpg' (num_crop_image)
# '1993.jpg' -> '3051.jpg' (num_crop_image)
# '1994.jpg' -> '3052.jpg' (num_crop_image)
# '1995.jpg' -> '3053.jpg' (num_crop_image)
# '1996.jpg' -> '3054.jpg' (num_crop_image)
# '1997.jpg' -> '3055.jpg' (num_crop_image)
# '1998.jpg' -> '3056.jpg' (num_crop_image)
# '1999.jpg' -> '3057.jpg' (num_crop_image)
# '200.jpg' -> '3058.jpg' (num_crop_image)
# '2000.jpg' -> '3059.jpg' (num_crop_image)
# '2001.jpg' -> '3060.jpg' (num_crop_image)
# '2002.jpg' -> '3061.jpg' (num_crop_image)
# '2003.jpg' -> '3062.jpg' (num_crop_image)
# '2004.jpg' -> '3063.jpg' (num_crop_image)
# '2005.jpg' -> '3064.jpg' (num_crop_image)
# '2006.jpg' -> '3065.jpg' (num_crop_image)
# '2007.jpg' -> '3066.jpg' (num_crop_image)
# '2008.jpg' -> '3067.jpg' (num_crop_image)
# '2009.jpg' -> '3068.jpg' (num_crop_image)
# '201.jpg' -> '3069.jpg' (num_crop_image)
# '2010.jpg' -> '3070.jpg' (num_crop_image)
# '2011.jpg' -> '3071.jpg' (num_crop_image)
# '2012.jpg' -> '3072.jpg' (num_crop_image)
# '2013.jpg' -> '3073.jpg' (num_crop_image)
# '2014.jpg' -> '3074.jpg' (num_crop_image)
# '2015.jpg' -> '3075.jpg' (num_crop_image)
# '2016.jpg' -> '3076.jpg' (num_crop_image)
# '2017.jpg' -> '3077.jpg' (num_crop_image)
# '2018.jpg' -> '3078.jpg' (num_crop_image)
# '2019.jpg' -> '3079.jpg' (num_crop_image)
# '202.jpg' -> '3080.jpg' (num_crop_image)
# '2020.jpg' -> '3081.jpg' (num_crop_image)
# '2021.jpg' -> '3082.jpg' (num_crop_image)
# '2022.jpg' -> '3083.jpg' (num_crop_image)
# '2023.jpg' -> '3084.jpg' (num_crop_image)
# '2024.jpg' -> '3085.jpg' (num_crop_image)
# '2025.jpg' -> '3086.jpg' (num_crop_image)
# '2026.jpg' -> '3087.jpg' (num_crop_image)
# '2027.jpg' -> '3088.jpg' (num_crop_image)
# '2028.jpg' -> '3089.jpg' (num_crop_image)
# '2029.jpg' -> '3090.jpg' (num_crop_image)
# '203.jpg' -> '3091.jpg' (num_crop_image)
# '2030.jpg' -> '3092.jpg' (num_crop_image)
# '2031.jpg' -> '3093.jpg' (num_crop_image)
# '2032.jpg' -> '3094.jpg' (num_crop_image)
# '2033.jpg' -> '3095.jpg' (num_crop_image)
# '2034.jpg' -> '3096.jpg' (num_crop_image)
# '2035.jpg' -> '3097.jpg' (num_crop_image)
# '2036.jpg' -> '3098.jpg' (num_crop_image)
# '2037.jpg' -> '3099.jpg' (num_crop_image)
# '2038.jpg' -> '3100.jpg' (num_crop_image)
# '2039.jpg' -> '3101.jpg' (num_crop_image)
# '204.jpg' -> '3102.jpg' (num_crop_image)
# '2040.jpg' -> '3103.jpg' (num_crop_image)
# '2041.jpg' -> '3104.jpg' (num_crop_image)
# '2042.jpg' -> '3105.jpg' (num_crop_image)
# '2043.jpg' -> '3106.jpg' (num_crop_image)
# '2044.jpg' -> '3107.jpg' (num_crop_image)
# '2045.jpg' -> '3108.jpg' (num_crop_image)
# '2046.jpg' -> '3109.jpg' (num_crop_image)
# '2047.jpg' -> '3110.jpg' (num_crop_image)
# '2048.jpg' -> '3111.jpg' (num_crop_image)
# '2049.jpg' -> '3112.jpg' (num_crop_image)
# '205.jpg' -> '3113.jpg' (num_crop_image)
# '2050.jpg' -> '3114.jpg' (num_crop_image)
# '2051.jpg' -> '3115.jpg' (num_crop_image)
# '2052.jpg' -> '3116.jpg' (num_crop_image)
# '2053.jpg' -> '3117.jpg' (num_crop_image)
# '2054.jpg' -> '3118.jpg' (num_crop_image)
# '2055.jpg' -> '3119.jpg' (num_crop_image)
# '2056.jpg' -> '3120.jpg' (num_crop_image)
# '2057.jpg' -> '3121.jpg' (num_crop_image)
# '2058.jpg' -> '3122.jpg' (num_crop_image)
# '2059.jpg' -> '3123.jpg' (num_crop_image)
# '206.jpg' -> '3124.jpg' (num_crop_image)
# '2060.jpg' -> '3125.jpg' (num_crop_image)
# '2061.jpg' -> '3126.jpg' (num_crop_image)
# '2062.jpg' -> '3127.jpg' (num_crop_image)
# '2063.jpg' -> '3128.jpg' (num_crop_image)
# '2064.jpg' -> '3129.jpg' (num_crop_image)
# '2065.jpg' -> '3130.jpg' (num_crop_image)
# '2066.jpg' -> '3131.jpg' (num_crop_image)
# '2067.jpg' -> '3132.jpg' (num_crop_image)
# '2068.jpg' -> '3133.jpg' (num_crop_image)
# '2069.jpg' -> '3134.jpg' (num_crop_image)
# '207.jpg' -> '3135.jpg' (num_crop_image)
# '2070.jpg' -> '3136.jpg' (num_crop_image)
# '2071.jpg' -> '3137.jpg' (num_crop_image)
# '2072.jpg' -> '3138.jpg' (num_crop_image)
# '2073.jpg' -> '3139.jpg' (num_crop_image)
# '2074.jpg' -> '3140.jpg' (num_crop_image)
# '2075.jpg' -> '3141.jpg' (num_crop_image)
# '2076.jpg' -> '3142.jpg' (num_crop_image)
# '2077.jpg' -> '3143.jpg' (num_crop_image)
# '2078.jpg' -> '3144.jpg' (num_crop_image)
# '2079.jpg' -> '3145.jpg' (num_crop_image)
# '208.jpg' -> '3146.jpg' (num_crop_image)
# '2080.jpg' -> '3147.jpg' (num_crop_image)
# '2081.jpg' -> '3148.jpg' (num_crop_image)
# '2082.jpg' -> '3149.jpg' (num_crop_image)
# '2083.jpg' -> '3150.jpg' (num_crop_image)
# '2084.jpg' -> '3151.jpg' (num_crop_image)
# '2085.jpg' -> '3152.jpg' (num_crop_image)
# '2086.jpg' -> '3153.jpg' (num_crop_image)
# '2087.jpg' -> '3154.jpg' (num_crop_image)
# '2088.jpg' -> '3155.jpg' (num_crop_image)
# '2089.jpg' -> '3156.jpg' (num_crop_image)
# '209.jpg' -> '3157.jpg' (num_crop_image)
# '2090.jpg' -> '3158.jpg' (num_crop_image)
# '2091.jpg' -> '3159.jpg' (num_crop_image)
# '2092.jpg' -> '3160.jpg' (num_crop_image)
# '2093.jpg' -> '3161.jpg' (num_crop_image)
# '2094.jpg' -> '3162.jpg' (num_crop_image)
# '2095.jpg' -> '3163.jpg' (num_crop_image)
# '2096.jpg' -> '3164.jpg' (num_crop_image)
# '2097.jpg' -> '3165.jpg' (num_crop_image)
# '2098.jpg' -> '3166.jpg' (num_crop_image)
# '2099.jpg' -> '3167.jpg' (num_crop_image)
# '210.jpg' -> '3168.jpg' (num_crop_image)
# '2100.jpg' -> '3169.jpg' (num_crop_image)
# '2101.jpg' -> '3170.jpg' (num_crop_image)
# '2102.jpg' -> '3171.jpg' (num_crop_image)
# '2103.jpg' -> '3172.jpg' (num_crop_image)
# '2104.jpg' -> '3173.jpg' (num_crop_image)
# '2105.jpg' -> '3174.jpg' (num_crop_image)
# '2106.jpg' -> '3175.jpg' (num_crop_image)
# '2107.jpg' -> '3176.jpg' (num_crop_image)
# '2108.jpg' -> '3177.jpg' (num_crop_image)
# '2109.jpg' -> '3178.jpg' (num_crop_image)
# '211.jpg' -> '3179.jpg' (num_crop_image)
# '2110.jpg' -> '3180.jpg' (num_crop_image)
# '2111.jpg' -> '3181.jpg' (num_crop_image)
# '2112.jpg' -> '3182.jpg' (num_crop_image)
# '212.jpg' -> '3183.jpg' (num_crop_image)
# '213.jpg' -> '3184.jpg' (num_crop_image)
# '214.jpg' -> '3185.jpg' (num_crop_image)
# '215.jpg' -> '3186.jpg' (num_crop_image)
# '216.jpg' -> '3187.jpg' (num_crop_image)
# '217.jpg' -> '3188.jpg' (num_crop_image)
# '218.jpg' -> '3189.jpg' (num_crop_image)
# '219.jpg' -> '3190.jpg' (num_crop_image)
# '220.jpg' -> '3191.jpg' (num_crop_image)
# '221.jpg' -> '3192.jpg' (num_crop_image)
# '222.jpg' -> '3193.jpg' (num_crop_image)
# ...
# 'annotated_738.jpg' -> 'annotated_3709.jpg' (num_crop_label)
# 'annotated_739.jpg' -> 'annotated_3710.jpg' (num_crop_label)
# 'annotated_740.jpg' -> 'annotated_3711.jpg' (num_crop_label)
# 'annotated_741.jpg' -> 'annotated_3712.jpg' (num_crop_label)
# 'annotated_742.jpg' -> 'annotated_3713.jpg' (num_crop_label)
# 'annotated_743.jpg' -> 'annotated_3714.jpg' (num_crop_label)
# 'annotated_744.jpg' -> 'annotated_3715.jpg' (num_crop_label)
# 'annotated_745.jpg' -> 'annotated_3716.jpg' (num_crop_label)
# 'annotated_746.jpg' -> 'annotated_3717.jpg' (num_crop_label)
# 'annotated_747.jpg' -> 'annotated_3718.jpg' (num_crop_label)
# 'annotated_748.jpg' -> 'annotated_3719.jpg' (num_crop_label)
# 'annotated_749.jpg' -> 'annotated_3720.jpg' (num_crop_label)
# 'annotated_750.jpg' -> 'annotated_3721.jpg' (num_crop_label)
# 'annotated_751.jpg' -> 'annotated_3722.jpg' (num_crop_label)
# 'annotated_752.jpg' -> 'annotated_3723.jpg' (num_crop_label)
# 'annotated_753.jpg' -> 'annotated_3724.jpg' (num_crop_label)
# 'annotated_754.jpg' -> 'annotated_3725.jpg' (num_crop_label)
# 'annotated_755.jpg' -> 'annotated_3726.jpg' (num_crop_label)
# 'annotated_756.jpg' -> 'annotated_3727.jpg' (num_crop_label)
# 'annotated_757.jpg' -> 'annotated_3728.jpg' (num_crop_label)
# 'annotated_758.jpg' -> 'annotated_3729.jpg' (num_crop_label)
# 'annotated_759.jpg' -> 'annotated_3730.jpg' (num_crop_label)
# 'annotated_760.jpg' -> 'annotated_3731.jpg' (num_crop_label)
# 'annotated_761.jpg' -> 'annotated_3732.jpg' (num_crop_label)
# 'annotated_762.jpg' -> 'annotated_3733.jpg' (num_crop_label)
# 'annotated_763.jpg' -> 'annotated_3734.jpg' (num_crop_label)
# 'annotated_764.jpg' -> 'annotated_3735.jpg' (num_crop_label)
# 'annotated_765.jpg' -> 'annotated_3736.jpg' (num_crop_label)
# 'annotated_766.jpg' -> 'annotated_3737.jpg' (num_crop_label)
# 'annotated_767.jpg' -> 'annotated_3738.jpg' (num_crop_label)
# 'annotated_768.jpg' -> 'annotated_3739.jpg' (num_crop_label)
# 'annotated_769.jpg' -> 'annotated_3740.jpg' (num_crop_label)
# 'annotated_770.jpg' -> 'annotated_3741.jpg' (num_crop_label)
# 'annotated_771.jpg' -> 'annotated_3742.jpg' (num_crop_label)
# 'annotated_772.jpg' -> 'annotated_3743.jpg' (num_crop_label)
# 'annotated_773.jpg' -> 'annotated_3744.jpg' (num_crop_label)
# 'annotated_774.jpg' -> 'annotated_3745.jpg' (num_crop_label)
# 'annotated_775.jpg' -> 'annotated_3746.jpg' (num_crop_label)
# 'annotated_776.jpg' -> 'annotated_3747.jpg' (num_crop_label)
# 'annotated_777.jpg' -> 'annotated_3748.jpg' (num_crop_label)
# 'annotated_778.jpg' -> 'annotated_3749.jpg' (num_crop_label)
# 'annotated_779.jpg' -> 'annotated_3750.jpg' (num_crop_label)
# 'annotated_780.jpg' -> 'annotated_3751.jpg' (num_crop_label)
# 'annotated_781.jpg' -> 'annotated_3752.jpg' (num_crop_label)
# 'annotated_782.jpg' -> 'annotated_3753.jpg' (num_crop_label)
# 'annotated_783.jpg' -> 'annotated_3754.jpg' (num_crop_label)
# 'annotated_784.jpg' -> 'annotated_3755.jpg' (num_crop_label)
# 'annotated_785.jpg' -> 'annotated_3756.jpg' (num_crop_label)
# 'annotated_786.jpg' -> 'annotated_3757.jpg' (num_crop_label)
# 'annotated_787.jpg' -> 'annotated_3758.jpg' (num_crop_label)
# 'annotated_788.jpg' -> 'annotated_3759.jpg' (num_crop_label)
# 'annotated_789.jpg' -> 'annotated_3760.jpg' (num_crop_label)
# 'annotated_790.jpg' -> 'annotated_3761.jpg' (num_crop_label)
# 'annotated_791.jpg' -> 'annotated_3762.jpg' (num_crop_label)
# 'annotated_792.jpg' -> 'annotated_3763.jpg' (num_crop_label)
# 'annotated_793.jpg' -> 'annotated_3764.jpg' (num_crop_label)
# 'annotated_794.jpg' -> 'annotated_3765.jpg' (num_crop_label)
# 'annotated_795.jpg' -> 'annotated_3766.jpg' (num_crop_label)
# 'annotated_796.jpg' -> 'annotated_3767.jpg' (num_crop_label)
# 'annotated_797.jpg' -> 'annotated_3768.jpg' (num_crop_label)
# 'annotated_798.jpg' -> 'annotated_3769.jpg' (num_crop_label)
# 'annotated_799.jpg' -> 'annotated_3770.jpg' (num_crop_label)
# 'annotated_800.jpg' -> 'annotated_3771.jpg' (num_crop_label)
# 'annotated_801.jpg' -> 'annotated_3772.jpg' (num_crop_label)
# 'annotated_802.jpg' -> 'annotated_3773.jpg' (num_crop_label)
# 'annotated_803.jpg' -> 'annotated_3774.jpg' (num_crop_label)
# 'annotated_804.jpg' -> 'annotated_3775.jpg' (num_crop_label)
# 'annotated_805.jpg' -> 'annotated_3776.jpg' (num_crop_label)
# 'annotated_806.jpg' -> 'annotated_3777.jpg' (num_crop_label)
# 'annotated_807.jpg' -> 'annotated_3778.jpg' (num_crop_label)
# 'annotated_808.jpg' -> 'annotated_3779.jpg' (num_crop_label)
# 'annotated_809.jpg' -> 'annotated_3780.jpg' (num_crop_label)
# 'annotated_810.jpg' -> 'annotated_3781.jpg' (num_crop_label)
# 'annotated_811.jpg' -> 'annotated_3782.jpg' (num_crop_label)
# 'annotated_812.jpg' -> 'annotated_3783.jpg' (num_crop_label)
# 'annotated_813.jpg' -> 'annotated_3784.jpg' (num_crop_label)
# 'annotated_814.jpg' -> 'annotated_3785.jpg' (num_crop_label)
# 'annotated_815.jpg' -> 'annotated_3786.jpg' (num_crop_label)
# 'annotated_816.jpg' -> 'annotated_3787.jpg' (num_crop_label)
# 'annotated_817.jpg' -> 'annotated_3788.jpg' (num_crop_label)
# 'annotated_818.jpg' -> 'annotated_3789.jpg' (num_crop_label)
# 'annotated_819.jpg' -> 'annotated_3790.jpg' (num_crop_label)
# 'annotated_820.jpg' -> 'annotated_3791.jpg' (num_crop_label)
# 'annotated_821.jpg' -> 'annotated_3792.jpg' (num_crop_label)
# 'annotated_822.jpg' -> 'annotated_3793.jpg' (num_crop_label)
# 'annotated_823.jpg' -> 'annotated_3794.jpg' (num_crop_label)
# 'annotated_824.jpg' -> 'annotated_3795.jpg' (num_crop_label)
# 'annotated_825.jpg' -> 'annotated_3796.jpg' (num_crop_label)
# 'annotated_826.jpg' -> 'annotated_3797.jpg' (num_crop_label)
# 'annotated_827.jpg' -> 'annotated_3798.jpg' (num_crop_label)
# 'annotated_828.jpg' -> 'annotated_3799.jpg' (num_crop_label)
# 'annotated_829.jpg' -> 'annotated_3800.jpg' (num_crop_label)
# 'annotated_830.jpg' -> 'annotated_3801.jpg' (num_crop_label)
# 'annotated_831.jpg' -> 'annotated_3802.jpg' (num_crop_label)
# 'annotated_832.jpg' -> 'annotated_3803.jpg' (num_crop_label)
# 'annotated_833.jpg' -> 'annotated_3804.jpg' (num_crop_label)
# 'annotated_834.jpg' -> 'annotated_3805.jpg' (num_crop_label)
# 'annotated_835.jpg' -> 'annotated_3806.jpg' (num_crop_label)
# 'annotated_836.jpg' -> 'annotated_3807.jpg' (num_crop_label)
# 'annotated_837.jpg' -> 'annotated_3808.jpg' (num_crop_label)
# 'annotated_838.jpg' -> 'annotated_3809.jpg' (num_crop_label)
# 'annotated_839.jpg' -> 'annotated_3810.jpg' (num_crop_label)
# 'annotated_840.jpg' -> 'annotated_3811.jpg' (num_crop_label)
# 'annotated_841.jpg' -> 'annotated_3812.jpg' (num_crop_label)
# 'annotated_842.jpg' -> 'annotated_3813.jpg' (num_crop_label)
# 'annotated_843.jpg' -> 'annotated_3814.jpg' (num_crop_label)
# 'annotated_844.jpg' -> 'annotated_3815.jpg' (num_crop_label)
# 'annotated_845.jpg' -> 'annotated_3816.jpg' (num_crop_label)
# 'annotated_846.jpg' -> 'annotated_3817.jpg' (num_crop_label)
# 'annotated_847.jpg' -> 'annotated_3818.jpg' (num_crop_label)
# 'annotated_848.jpg' -> 'annotated_3819.jpg' (num_crop_label)
# 'annotated_849.jpg' -> 'annotated_3820.jpg' (num_crop_label)
# 'annotated_850.jpg' -> 'annotated_3821.jpg' (num_crop_label)
# 'annotated_851.jpg' -> 'annotated_3822.jpg' (num_crop_label)
# 'annotated_852.jpg' -> 'annotated_3823.jpg' (num_crop_label)
# 'annotated_853.jpg' -> 'annotated_3824.jpg' (num_crop_label)
# 'annotated_854.jpg' -> 'annotated_3825.jpg' (num_crop_label)
# 'annotated_855.jpg' -> 'annotated_3826.jpg' (num_crop_label)
# 'annotated_856.jpg' -> 'annotated_3827.jpg' (num_crop_label)
# 'annotated_857.jpg' -> 'annotated_3828.jpg' (num_crop_label)
# 'annotated_858.jpg' -> 'annotated_3829.jpg' (num_crop_label)
# 'annotated_859.jpg' -> 'annotated_3830.jpg' (num_crop_label)
# 'annotated_860.jpg' -> 'annotated_3831.jpg' (num_crop_label)
# 'annotated_861.jpg' -> 'annotated_3832.jpg' (num_crop_label)
# 'annotated_862.jpg' -> 'annotated_3833.jpg' (num_crop_label)
# 'annotated_863.jpg' -> 'annotated_3834.jpg' (num_crop_label)
# 'annotated_864.jpg' -> 'annotated_3835.jpg' (num_crop_label)
# 'annotated_865.jpg' -> 'annotated_3836.jpg' (num_crop_label)
# 'annotated_866.jpg' -> 'annotated_3837.jpg' (num_crop_label)
# 'annotated_867.jpg' -> 'annotated_3838.jpg' (num_crop_label)
# 'annotated_868.jpg' -> 'annotated_3839.jpg' (num_crop_label)
# 'annotated_869.jpg' -> 'annotated_3840.jpg' (num_crop_label)
# 'annotated_870.jpg' -> 'annotated_3841.jpg' (num_crop_label)
# 'annotated_871.jpg' -> 'annotated_3842.jpg' (num_crop_label)
# 'annotated_872.jpg' -> 'annotated_3843.jpg' (num_crop_label)
# 'annotated_873.jpg' -> 'annotated_3844.jpg' (num_crop_label)
# 'annotated_874.jpg' -> 'annotated_3845.jpg' (num_crop_label)
# 'annotated_875.jpg' -> 'annotated_3846.jpg' (num_crop_label)
# 'annotated_876.jpg' -> 'annotated_3847.jpg' (num_crop_label)
# 'annotated_877.jpg' -> 'annotated_3848.jpg' (num_crop_label)
# 'annotated_878.jpg' -> 'annotated_3849.jpg' (num_crop_label)
# 'annotated_879.jpg' -> 'annotated_3850.jpg' (num_crop_label)
# 'annotated_880.jpg' -> 'annotated_3851.jpg' (num_crop_label)
# 'annotated_881.jpg' -> 'annotated_3852.jpg' (num_crop_label)
# 'annotated_882.jpg' -> 'annotated_3853.jpg' (num_crop_label)
# 'annotated_883.jpg' -> 'annotated_3854.jpg' (num_crop_label)
# 'annotated_884.jpg' -> 'annotated_3855.jpg' (num_crop_label)
# 'annotated_885.jpg' -> 'annotated_3856.jpg' (num_crop_label)
# 'annotated_886.jpg' -> 'annotated_3857.jpg' (num_crop_label)
# 'annotated_887.jpg' -> 'annotated_3858.jpg' (num_crop_label)
# 'annotated_888.jpg' -> 'annotated_3859.jpg' (num_crop_label)
# 'annotated_889.jpg' -> 'annotated_3860.jpg' (num_crop_label)
# 'annotated_890.jpg' -> 'annotated_3861.jpg' (num_crop_label)
# 'annotated_891.jpg' -> 'annotated_3862.jpg' (num_crop_label)
# 'annotated_892.jpg' -> 'annotated_3863.jpg' (num_crop_label)
# 'annotated_893.jpg' -> 'annotated_3864.jpg' (num_crop_label)
# 'annotated_894.jpg' -> 'annotated_3865.jpg' (num_crop_label)
# 'annotated_895.jpg' -> 'annotated_3866.jpg' (num_crop_label)
# 'annotated_896.jpg' -> 'annotated_3867.jpg' (num_crop_label)
# 'annotated_897.jpg' -> 'annotated_3868.jpg' (num_crop_label)
# 'annotated_898.jpg' -> 'annotated_3869.jpg' (num_crop_label)
# 'annotated_899.jpg' -> 'annotated_3870.jpg' (num_crop_label)
# 'annotated_900.jpg' -> 'annotated_3871.jpg' (num_crop_label)
# 'annotated_901.jpg' -> 'annotated_3872.jpg' (num_crop_label)
# 'annotated_902.jpg' -> 'annotated_3873.jpg' (num_crop_label)
# 'annotated_903.jpg' -> 'annotated_3874.jpg' (num_crop_label)
# 'annotated_904.jpg' -> 'annotated_3875.jpg' (num_crop_label)
# 'annotated_905.jpg' -> 'annotated_3876.jpg' (num_crop_label)
# 'annotated_906.jpg' -> 'annotated_3877.jpg' (num_crop_label)
# 'annotated_907.jpg' -> 'annotated_3878.jpg' (num_crop_label)
# 'annotated_908.jpg' -> 'annotated_3879.jpg' (num_crop_label)
# 'annotated_909.jpg' -> 'annotated_3880.jpg' (num_crop_label)
# 'annotated_910.jpg' -> 'annotated_3881.jpg' (num_crop_label)
# 'annotated_911.jpg' -> 'annotated_3882.jpg' (num_crop_label)
# 'annotated_912.jpg' -> 'annotated_3883.jpg' (num_crop_label)
# 'annotated_913.jpg' -> 'annotated_3884.jpg' (num_crop_label)
# 'annotated_914.jpg' -> 'annotated_3885.jpg' (num_crop_label)
# 'annotated_915.jpg' -> 'annotated_3886.jpg' (num_crop_label)
# 'annotated_916.jpg' -> 'annotated_3887.jpg' (num_crop_label)
# 'annotated_917.jpg' -> 'annotated_3888.jpg' (num_crop_label)
# 'annotated_918.jpg' -> 'annotated_3889.jpg' (num_crop_label)
# 'annotated_919.jpg' -> 'annotated_3890.jpg' (num_crop_label)
# 'annotated_920.jpg' -> 'annotated_3891.jpg' (num_crop_label)
# 'annotated_921.jpg' -> 'annotated_3892.jpg' (num_crop_label)
# 'annotated_922.jpg' -> 'annotated_3893.jpg' (num_crop_label)
# 'annotated_923.jpg' -> 'annotated_3894.jpg' (num_crop_label)
# 'annotated_924.jpg' -> 'annotated_3895.jpg' (num_crop_label)
# 'annotated_925.jpg' -> 'annotated_3896.jpg' (num_crop_label)
# 'annotated_926.jpg' -> 'annotated_3897.jpg' (num_crop_label)
# 'annotated_927.jpg' -> 'annotated_3898.jpg' (num_crop_label)
# 'annotated_928.jpg' -> 'annotated_3899.jpg' (num_crop_label)
# 'annotated_929.jpg' -> 'annotated_3900.jpg' (num_crop_label)
# 'annotated_930.jpg' -> 'annotated_3901.jpg' (num_crop_label)
# 'annotated_931.jpg' -> 'annotated_3902.jpg' (num_crop_label)
# 'annotated_932.jpg' -> 'annotated_3903.jpg' (num_crop_label)
# 'annotated_933.jpg' -> 'annotated_3904.jpg' (num_crop_label)
# 'annotated_934.jpg' -> 'annotated_3905.jpg' (num_crop_label)
# 'annotated_935.jpg' -> 'annotated_3906.jpg' (num_crop_label)
# 'annotated_936.jpg' -> 'annotated_3907.jpg' (num_crop_label)
# 'annotated_937.jpg' -> 'annotated_3908.jpg' (num_crop_label)
# 'annotated_938.jpg' -> 'annotated_3909.jpg' (num_crop_label)
# 'annotated_939.jpg' -> 'annotated_3910.jpg' (num_crop_label)
# 'annotated_940.jpg' -> 'annotated_3911.jpg' (num_crop_label)
# 'annotated_941.jpg' -> 'annotated_3912.jpg' (num_crop_label)
# 'annotated_942.jpg' -> 'annotated_3913.jpg' (num_crop_label)
# 'annotated_943.jpg' -> 'annotated_3914.jpg' (num_crop_label)
# 'annotated_944.jpg' -> 'annotated_3915.jpg' (num_crop_label)
# 'annotated_945.jpg' -> 'annotated_3916.jpg' (num_crop_label)
# 'annotated_946.jpg' -> 'annotated_3917.jpg' (num_crop_label)
# 'annotated_947.jpg' -> 'annotated_3918.jpg' (num_crop_label)
# 'annotated_948.jpg' -> 'annotated_3919.jpg' (num_crop_label)
# 'annotated_949.jpg' -> 'annotated_3920.jpg' (num_crop_label)
# 'annotated_950.jpg' -> 'annotated_3921.jpg' (num_crop_label)
# 'annotated_951.jpg' -> 'annotated_3922.jpg' (num_crop_label)
# 'annotated_952.jpg' -> 'annotated_3923.jpg' (num_crop_label)
# 'annotated_953.jpg' -> 'annotated_3924.jpg' (num_crop_label)
# 'annotated_954.jpg' -> 'annotated_3925.jpg' (num_crop_label)
# 'annotated_955.jpg' -> 'annotated_3926.jpg' (num_crop_label)
# 'annotated_956.jpg' -> 'annotated_3927.jpg' (num_crop_label)
# 'annotated_957.jpg' -> 'annotated_3928.jpg' (num_crop_label)
# 'annotated_958.jpg' -> 'annotated_3929.jpg' (num_crop_label)
# 'annotated_959.jpg' -> 'annotated_3930.jpg' (num_crop_label)
# 'annotated_960.jpg' -> 'annotated_3931.jpg' (num_crop_label)
# 'annotated_961.jpg' -> 'annotated_3932.jpg' (num_crop_label)
# 'annotated_962.jpg' -> 'annotated_3933.jpg' (num_crop_label)
# 'annotated_963.jpg' -> 'annotated_3934.jpg' (num_crop_label)
# 'annotated_964.jpg' -> 'annotated_3935.jpg' (num_crop_label)
# 'annotated_965.jpg' -> 'annotated_3936.jpg' (num_crop_label)
# 'annotated_966.jpg' -> 'annotated_3937.jpg' (num_crop_label)
# 'annotated_967.jpg' -> 'annotated_3938.jpg' (num_crop_label)
# 'annotated_968.jpg' -> 'annotated_3939.jpg' (num_crop_label)
# 'annotated_969.jpg' -> 'annotated_3940.jpg' (num_crop_label)
# 'annotated_970.jpg' -> 'annotated_3941.jpg' (num_crop_label)
# 'annotated_971.jpg' -> 'annotated_3942.jpg' (num_crop_label)
# 'annotated_972.jpg' -> 'annotated_3943.jpg' (num_crop_label)
# 'annotated_973.jpg' -> 'annotated_3944.jpg' (num_crop_label)
# 'annotated_974.jpg' -> 'annotated_3945.jpg' (num_crop_label)
# 'annotated_975.jpg' -> 'annotated_3946.jpg' (num_crop_label)
# 'annotated_976.jpg' -> 'annotated_3947.jpg' (num_crop_label)
# 'annotated_977.jpg' -> 'annotated_3948.jpg' (num_crop_label)
# 'annotated_978.jpg' -> 'annotated_3949.jpg' (num_crop_label)
# 'annotated_979.jpg' -> 'annotated_3950.jpg' (num_crop_label)
# 'annotated_980.jpg' -> 'annotated_3951.jpg' (num_crop_label)
# 'annotated_981.jpg' -> 'annotated_3952.jpg' (num_crop_label)
# 'annotated_982.jpg' -> 'annotated_3953.jpg' (num_crop_label)
# 'annotated_983.jpg' -> 'annotated_3954.jpg' (num_crop_label)
# 'annotated_984.jpg' -> 'annotated_3955.jpg' (num_crop_label)
# 'annotated_985.jpg' -> 'annotated_3956.jpg' (num_crop_label)
# 'annotated_986.jpg' -> 'annotated_3957.jpg' (num_crop_label)
# 'annotated_987.jpg' -> 'annotated_3958.jpg' (num_crop_label)
# 'annotated_988.jpg' -> 'annotated_3959.jpg' (num_crop_label)
# 'annotated_989.jpg' -> 'annotated_3960.jpg' (num_crop_label)
# 'annotated_990.jpg' -> 'annotated_3961.jpg' (num_crop_label)
# 'annotated_991.jpg' -> 'annotated_3962.jpg' (num_crop_label)
# 'annotated_992.jpg' -> 'annotated_3963.jpg' (num_crop_label)
# 'annotated_993.jpg' -> 'annotated_3964.jpg' (num_crop_label)
# 'annotated_994.jpg' -> 'annotated_3965.jpg' (num_crop_label)
# 'annotated_995.jpg' -> 'annotated_3966.jpg' (num_crop_label)
# 'annotated_996.jpg' -> 'annotated_3967.jpg' (num_crop_label)
# 'annotated_997.jpg' -> 'annotated_3968.jpg' (num_crop_label)
# 'annotated_998.jpg' -> 'annotated_3969.jpg' (num_crop_label)
# 'annotated_999.jpg' -> 'annotated_3970.jpg' (num_crop_label)
